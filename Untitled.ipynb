# %%
# %%HTML
# <table>
#     <thead>
#     <tr>
#         <td>bg</td><td>cs</td><td>da</td><td>de</td><td>de_x_sie</td><td>el</td><td>en</td><td>en_us</td><td>es</td><td>es_x_tu</td><td>fr</td><td>hr</td><td>it</td><td>nl</td><td>pl</td><td>pt</td><td>pt_br</td><td>ru</td><td>sk</td><td>tr</td><td>zh_cmn_hans</td>
#     </tr>
#     </thead>
#     <tbody>
#         <tr>
#             <td>CAPITAL_ACP_HS</td><td></td><td></td><td></td><td></td><td></td><td></td><td></td><td></td><td></td><td></td><td></td><td></td><td></td><td></td><td></td><td></td><td></td><td></td><td></td><td></td>
#         </tr>
#         <tr>
#             <td>CAPITAL_ALL_HS</td><td></td><td></td><td></td><td></td><td></td><td></td><td></td><td></td><td></td><td></td><td></td><td></td><td></td><td></td><td></td><td></td><td></td><td></td><td></td><td></td>
#         </tr>
#         <tr>
#             <td>CAPITAL_EMAIL_HS</td><td></td><td></td><td></td><td></td><td></td><td></td><td></td><td></td><td></td><td></td><td></td><td></td><td></td><td></td><td></td><td></td><td></td><td></td><td></td><td></td>
#         </tr>
#         <tr>
#             <td>CAPITAL_FORUMS_HS</td><td></td><td></td><td></td><td></td><td></td><td></td><td></td><td></td><td></td><td></td><td></td><td></td><td></td><td></td><td></td><td></td><td></td><td></td><td></td><td></td>
#         </tr>
#         <tr>
#             <td>CAPITAL_DISCUSSIONS_HS</td><td></td><td></td><td></td><td></td><td></td><td></td><td></td><td></td><td></td><td></td><td></td><td></td><td></td><td></td><td></td><td></td><td></td><td></td><td></td><td></td>
#         </tr>
#         <tr>
#             <td>CAPITAL_UNREAD_HS</td><td></td><td></td><td></td><td></td><td></td><td></td><td></td><td></td><td></td><td></td><td></td><td></td><td></td><td></td><td></td><td></td><td></td><td></td><td></td><td></td>
#         </tr>
#         <tr>
#             <td>CAPITAL_SUBSCRIBED_HS</td><td></td><td></td><td></td><td></td><td></td><td></td><td></td><td></td><td></td><td></td><td></td><td></td><td></td><td></td><td></td><td></td><td></td><td></td><td></td><td></td>
#         </tr>
#         <tr>
#             <td>CAPITAL_PARTICIPATED_HS</td><td></td><td></td><td></td><td></td><td></td><td></td><td></td><td></td><td></td><td></td><td></td><td></td><td></td><td></td><td></td><td></td><td></td><td></td><td></td><td></td>
#         </tr>
#         <tr>
#             <td>CAPITAL_CONFIRMATION_HS</td><td></td><td></td><td></td><td></td><td></td><td></td><td></td><td></td><td></td><td></td><td></td><td></td><td></td><td></td><td></td><td></td><td></td><td></td><td></td><td></td>
#         </tr>
#         <tr>
#             <td>CAPITAL_URL_HS</td><td></td><td></td><td></td><td></td><td></td><td></td><td></td><td></td><td></td><td></td><td></td><td></td><td></td><td></td><td></td><td></td><td></td><td></td><td></td><td></td>
#         </tr>
#         <tr>
#             <td>SOMEONE_MENTIONED_YOU_HS</td><td></td><td></td><td></td><td></td><td></td><td></td><td></td><td></td><td></td><td></td><td></td><td></td><td></td><td></td><td></td><td></td><td></td><td></td><td></td><td></td>
#         </tr>
#         <tr>
#             <td>IS_MARRIED_HS</td><td></td><td></td><td></td><td></td><td></td><td></td><td></td><td></td><td></td><td></td><td></td><td></td><td></td><td></td><td></td><td></td><td></td><td></td><td></td><td></td>
#         </tr>
#         <tr>
#             <td>INTERESTS_HS</td><td></td><td></td><td></td><td></td><td></td><td></td><td></td><td></td><td></td><td></td><td></td><td></td><td></td><td></td><td></td><td></td><td></td><td></td><td></td><td></td>
#         </tr>
#         <tr>
#             <td>NUMBERS_HS</td><td></td><td></td><td></td><td></td><td></td><td></td><td></td><td></td><td></td><td></td><td></td><td></td><td></td><td></td><td></td><td></td><td></td><td></td><td></td><td></td>
#         </tr>
#         <tr>
#             <td>BANNED_USERS_HS</td><td></td><td></td><td></td><td></td><td></td><td></td><td></td><td></td><td></td><td></td><td></td><td></td><td></td><td></td><td></td><td></td><td></td><td></td><td></td><td></td>
#         </tr>
#         <tr>
#             <td>FORUM_OWNERS_TAPATALK_ACTIVATED_HS</td><td></td><td></td><td></td><td></td><td></td><td></td><td></td><td></td><td></td><td></td><td></td><td></td><td></td><td></td><td></td><td></td><td></td><td></td><td></td><td></td>
#         </tr>
#         <tr>
#             <td>REGISTERED_FROM_TAPATALK_APP_HS</td><td></td><td></td><td></td><td></td><td></td><td></td><td></td><td></td><td></td><td></td><td></td><td></td><td></td><td></td><td></td><td></td><td></td><td></td><td></td><td></td>
#         </tr>
#         <tr>
#             <td>SUPER_MODERATORS_HS</td><td></td><td></td><td></td><td></td><td></td><td></td><td></td><td></td><td></td><td></td><td></td><td></td><td></td><td></td><td></td><td></td><td></td><td></td><td></td><td></td>
#         </tr>
#         <tr>
#             <td>MANAGE_SETTING_HS</td><td></td><td></td><td></td><td></td><td></td><td></td><td></td><td></td><td></td><td></td><td></td><td></td><td></td><td></td><td></td><td></td><td></td><td></td><td></td><td></td>
#         </tr>
#         <tr>
#             <td>CUSTOMIZE_LOOK_AND_FEED_HS</td><td></td><td></td><td></td><td></td><td></td><td></td><td></td><td></td><td></td><td></td><td></td><td></td><td></td><td></td><td></td><td></td><td></td><td></td><td></td><td></td>
#         </tr>
#         <tr>
#             <td>TAPATALK_CONSOLE_HS</td><td></td><td></td><td></td><td></td><td></td><td></td><td></td><td></td><td></td><td></td><td></td><td></td><td></td><td></td><td></td><td></td><td></td><td></td><td></td><td></td>
#         </tr>
#         <tr>
#             <td>ALL_POSTS_HS</td><td></td><td></td><td></td><td></td><td></td><td></td><td></td><td></td><td></td><td></td><td></td><td></td><td></td><td></td><td></td><td></td><td></td><td></td><td></td><td></td>
#         </tr>
#         <tr>
#             <td>SMALLER_HS</td><td></td><td></td><td></td><td></td><td></td><td></td><td></td><td></td><td></td><td></td><td></td><td></td><td></td><td></td><td></td><td></td><td></td><td></td><td></td><td></td>
#         </tr>
#         <tr>
#             <td>LARGER_HS</td><td></td><td></td><td></td><td></td><td></td><td></td><td></td><td></td><td></td><td></td><td></td><td></td><td></td><td></td><td></td><td></td><td></td><td></td><td></td><td></td>
#         </tr>
#         <tr>
#             <td>LEFT_HS</td><td></td><td></td><td></td><td></td><td></td><td></td><td></td><td></td><td></td><td></td><td></td><td></td><td></td><td></td><td></td><td></td><td></td><td></td><td></td><td></td>
#         </tr>
#         <tr>
#             <td>CENTER_HS</td><td></td><td></td><td></td><td></td><td></td><td></td><td></td><td></td><td></td><td></td><td></td><td></td><td></td><td></td><td></td><td></td><td></td><td></td><td></td><td></td>
#         </tr>
#         <tr>
#             <td>RIGHT_HS</td><td></td><td></td><td></td><td></td><td></td><td></td><td></td><td></td><td></td><td></td><td></td><td></td><td></td><td></td><td></td><td></td><td></td><td></td><td></td><td></td>
#         </tr>
#         <tr>
#             <td>JUSTIFY_HS</td><td></td><td></td><td></td><td></td><td></td><td></td><td></td><td></td><td></td><td></td><td></td><td></td><td></td><td></td><td></td><td></td><td></td><td></td><td></td><td></td>
#         </tr>
#         <tr>
#             <td>COLS_HS</td><td></td><td></td><td></td><td></td><td></td><td></td><td></td><td></td><td></td><td></td><td></td><td></td><td></td><td></td><td></td><td></td><td></td><td></td><td></td><td></td>
#         </tr>
#         <tr>
#             <td>ATTACH_PHOTO_OR_FILE_HS</td><td></td><td></td><td></td><td></td><td></td><td></td><td></td><td></td><td></td><td></td><td></td><td></td><td></td><td></td><td></td><td></td><td></td><td></td><td></td><td></td>
#         </tr>
#         <tr>
#             <td>DESCRIPTION_HS</td><td></td><td></td><td></td><td></td><td></td><td></td><td></td><td></td><td></td><td></td><td></td><td></td><td></td><td></td><td></td><td></td><td></td><td></td><td></td><td></td>
#         </tr>
#         <tr>
#             <td>OPTIONAL_HS</td><td></td><td></td><td></td><td></td><td></td><td></td><td></td><td></td><td></td><td></td><td></td><td></td><td></td><td></td><td></td><td></td><td></td><td></td><td></td><td></td>
#         </tr>
#         <tr>
#             <td>VIEW_AS_ORIGINAL_POST_HS</td><td></td><td></td><td></td><td></td><td></td><td></td><td></td><td></td><td></td><td></td><td></td><td></td><td></td><td></td><td></td><td></td><td></td><td></td><td></td><td></td>
#         </tr>
#         <tr>
#             <td>VIEW_SOURCE_HS</td><td></td><td></td><td></td><td></td><td></td><td></td><td></td><td></td><td></td><td></td><td></td><td></td><td></td><td></td><td></td><td></td><td></td><td></td><td></td><td></td>
#         </tr>
#         <tr>
#             <td>UNREAD_HS</td><td></td><td></td><td></td><td></td><td></td><td></td><td></td><td></td><td></td><td></td><td></td><td></td><td></td><td></td><td></td><td></td><td></td><td></td><td></td><td></td>
#         </tr>
#         <tr>
#             <td>SUBSCRIBED_HS</td><td></td><td></td><td></td><td></td><td></td><td></td><td></td><td></td><td></td><td></td><td></td><td></td><td></td><td></td><td></td><td></td><td></td><td></td><td></td><td></td>
#         </tr>
#         <tr>
#             <td>MESSAGE_BODY_HS</td><td></td><td></td><td></td><td></td><td></td><td></td><td></td><td></td><td></td><td></td><td></td><td></td><td></td><td></td><td></td><td></td><td></td><td></td><td></td><td></td>
#         </tr>
#         <tr>
#             <td>BIRTHDAY_HS</td><td></td><td></td><td></td><td></td><td></td><td></td><td></td><td></td><td></td><td></td><td></td><td></td><td></td><td></td><td></td><td></td><td></td><td></td><td></td><td></td>
#         </tr>
#         <tr>
#             <td>PARTICIPATED_HS</td><td></td><td></td><td></td><td></td><td></td><td></td><td></td><td></td><td></td><td></td><td></td><td></td><td></td><td></td><td></td><td></td><td></td><td></td><td></td><td></td>
#         </tr>
#         <tr>
#             <td>SUBJECT_HS</td><td></td><td></td><td></td><td></td><td></td><td></td><td></td><td></td><td></td><td></td><td></td><td></td><td></td><td></td><td></td><td></td><td></td><td></td><td></td><td></td>
#         </tr>
#         <tr>
#             <td>SEND_EMAIL_HS</td><td></td><td></td><td></td><td></td><td></td><td></td><td></td><td></td><td></td><td></td><td></td><td></td><td></td><td></td><td></td><td></td><td></td><td></td><td></td><td></td>
#         </tr>
#         <tr>
#             <td>SUBSCRIBED_TOPICS_HS</td><td></td><td></td><td></td><td></td><td></td><td></td><td></td><td></td><td></td><td></td><td></td><td></td><td></td><td></td><td></td><td></td><td></td><td></td><td></td><td></td>
#         </tr>
#         <tr>
#             <td>REPLY_HS</td><td></td><td></td><td></td><td></td><td></td><td></td><td></td><td></td><td></td><td></td><td></td><td></td><td></td><td></td><td></td><td></td><td></td><td></td><td></td><td></td>
#         </tr>
#         <tr>
#             <td>SMALL_HS</td><td></td><td></td><td></td><td></td><td></td><td></td><td></td><td></td><td></td><td></td><td></td><td></td><td></td><td></td><td></td><td></td><td></td><td></td><td></td><td></td>
#         </tr>
#         <tr>
#             <td>NORMAL_HS</td><td></td><td></td><td></td><td></td><td></td><td></td><td></td><td></td><td></td><td></td><td></td><td></td><td></td><td></td><td></td><td></td><td></td><td></td><td></td><td></td>
#         </tr>
#         <tr>
#             <td>LARGE_HS</td><td></td><td></td><td></td><td></td><td></td><td></td><td></td><td></td><td></td><td></td><td></td><td></td><td></td><td></td><td></td><td></td><td></td><td></td><td></td><td></td>
#         </tr>
#         <tr>
#             <td>INSERT_HS</td><td></td><td></td><td></td><td></td><td></td><td></td><td></td><td></td><td></td><td></td><td></td><td></td><td></td><td></td><td></td><td></td><td></td><td></td><td></td><td></td>
#         </tr>
#         <tr>
#             <td>FONT_SIZE_HS</td><td></td><td></td><td></td><td></td><td></td><td></td><td></td><td></td><td></td><td></td><td></td><td></td><td></td><td></td><td></td><td></td><td></td><td></td><td></td><td></td>
#         </tr>
#         <tr>
#             <td>DISCUSSIONS_HS</td><td></td><td></td><td></td><td></td><td></td><td></td><td></td><td></td><td></td><td></td><td></td><td></td><td></td><td></td><td></td><td></td><td></td><td></td><td></td><td></td>
#         </tr>
#     </tbody>
# </table>
# Out:
# <table>
#     <thead>
#     <tr>
#         <td>bg</td><td>cs</td><td>da</td><td>de</td><td>de_x_sie</td><td>el</td><td>en</td><td>en_us</td><td>es</td><td>es_x_tu</td><td>fr</td><td>hr</td><td>it</td><td>nl</td><td>pl</td><td>pt</td><td>pt_br</td><td>ru</td><td>sk</td><td>tr</td><td>zh_cmn_hans</td>
#     </tr>
#     </thead>
#     <tbody>
#         <tr>
#             <td>CAPITAL_ACP_HS</td><td></td><td></td><td></td><td></td><td></td><td></td><td></td><td></td><td></td><td></td><td></td><td></td><td></td><td></td><td></td><td></td><td></td><td></td><td></td><td></td>
#         </tr>
#         <tr>
#             <td>CAPITAL_ALL_HS</td><td></td><td></td><td></td><td></td><td></td><td></td><td></td><td></td><td></td><td></td><td></td><td></td><td></td><td></td><td></td><td></td><td></td><td></td><td></td><td></td>
#         </tr>
#         <tr>
# ...
