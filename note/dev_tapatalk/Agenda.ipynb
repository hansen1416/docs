# %%
import time
import datetime

s = "2018/11/16"

t = time.mktime(datetime.datetime.strptime(s, "%Y/%m/%d").timetuple())

print(t)
# Out:
# 1542297600.0

# %% [markdown]
# 2020.1.15
#
# - the gap should be bigger between "11" and "comments"
# - ~~follow, unfollow => join, leave group. and join to be a big button.~~
# - return error message to app when the login token is expired.
# - ~~滚动条尽量贴在右边尽头~~
# - ~~Category => Category (optional)~~
# - ~~No need show "We are ready to upload your image", only show error message if there is an error~~
# - ~~change "save" to "Create Group"~~
# - ~~"create group" button always blue, show error message only when user click on it. don't show error message at the befinnning~~
# - ~~when click enter in a category input, it should go to a new empty category input.~~
# - ~~enable upload new cover image only after user cleared the uploaded file~~
# - ~~"manege" hover effect is wired, the icon shall be closer to the text~~
# - ~~click on the entire editor area should focus on the editor~~
# - ~~after send a new post, don't hide the editor~~
# - the load after sketeton should be hiddden, and need some padding adjustment
# - a UI indicate there is no more data to load
# - create a deep nested comments list.
# - sort by the first level posts, new, like, hot. the data should include all the nested posts.
#
# 2020.1.17
#
# - routes seo. use  https://www.everforo.com/g/everforo/all as home url
# - fix delete category.
# - a reset button for editor
# - focus on a input when user click new topic
# - subject placeholder font style different with editor placeholder
# - editor shall fill in the blank space of new topic poup
# - input multiple lines in editor can cause the editor overflow from popup
#
# 2020.1.18
#
# - when paste a long text in quick reply editor, the avatar has been squeezed to the top
# - when click reply, screen should scroll to a comfortable position that let user typing
# - after reply sent, clear the content in the reply editor
# - image in post reply shall has limited maxium size

# %% [markdown]
# - show category on thread list
# - quick topic editor
# - no new topic for guest
# - packing images in preview list
# - nsfw check remote images
# - notification popup, messenger
# - sort by API
# - edit topic modal
# - like API
# - left right column stick position to minus when content too long
# - thread list doesn't contain category info
# - post_count didn't inscrement when post comments
# - image block on resize
# - 快速回复编辑框右边溢出
# - remember scroll position
# - 记住滑动位置
# - add video input position is wrong
# - change sort is not reloading
# - remote images are not nsfw checked
# - deleted post popup upper no, lower yes
# - clear thread list store after new topic
# - image loading visual and movable
# - add postcss-css-variables
# - load mobile component on demand
# - timestring to timestamp, in database
#
# - rerfresh jwt, save jwt token in server cookie
#
# - dark mode
#
# - unit test

# %%
import base64
import json
from pprint import pprint

s = b"test11"
s1 = base64.b64encode(s)

# print(s1)

b = '''
MTIzNDU2
'''
b1 = base64.b64decode(b)
# b1 = json.loads(b1, strict=False)

# pprint(b1)

string = r'{}'
obj = json.loads(string, strict=False)

pprint(obj)
# Out:
# b'dGVzdDEx'
# b'123456'
# {}

# %%
import hashlib

s = b"1371050|27026624|weixing.han@tapatalk.com"
m = hashlib.md5(s)
print(m.hexdigest())
# Out:
# fcf9e1be365b25149727ba1025b6f0e8

# %% [markdown]
# enchantedforum, ready for production
#
# songofthepaddle, need admin account
#
# panicfreaks.org, need admin account
#
# gstrail, error
#
# wrongfitmentcrew, error
#
# gtsportstalk, wrong folder
# 巨西小区  中星张杨苑   西镇小区
# 四季全景台花苑   大唐盛世花园
# 花木苑  牡丹小区  金桂小区  蓝高小区
# 香梅花园

# %% [markdown]
# define("PAYPAL_PREMIUM_PLAN1", "P-5UY56067P29547800QAABUPI");
# define("PAYPAL_PREMIUM_PLAN2", "P-4D229310SF584243GQAAEGIA");
# define("PAYPAL_PREMIUM_PLAN3", "P-1JG37503015909849QAAG6IQ");
# define("PAYPAL_PREMIUM_PLAN5", "P-3NC06234HL2873004QAAJVKA");
# define("PAYPAL_PREMIUM_PLAN10", "P-50A74511EP474221BQAA7FWA");
# define("PAYPAL_PREMIUM_PLAN20", "P-7FW35438S62052009QABBZZQ");
# define("PAYPAL_PREMIUM_PLAN50", "P-80X99002F86407909QABE2MY");
# define("PAYPAL_PREMIUM_PLAN100", "P-98W985449Y011253CQABHQOA");
#
#
# define("PAYPAL_PREMIUM_PLAN1", "P-49F67715M6628784LPKMJQHQ");
# define("PAYPAL_PREMIUM_PLAN2", "P-8JE99714J74824942PKMLFTI");
# define("PAYPAL_PREMIUM_PLAN3", "P-8MP03768NS649745BPKMM42Q");
# define("PAYPAL_PREMIUM_PLAN5", "P-6E0132429M817841EPKMOP6Y");
# define("PAYPAL_PREMIUM_PLAN10", "P-6HY07935WR7831403PKMQC3A");
# define("PAYPAL_PREMIUM_PLAN20", "P-4KG056566G0727135PKMR4UA");
# define("PAYPAL_PREMIUM_PLAN50", "P-3SD7728756814582FPKMTQSA");
# define("PAYPAL_PREMIUM_PLAN100", "P-09043995VE245994UPKMVEFA");

# %% [markdown]
# select count(*), MONTH(FROM_UNIXTIME(post_time)), YEAR(FROM_UNIXTIME(post_time)) from hs_myfreeforum_2.modelsteam_posts
# where DATE(FROM_UNIXTIME(post_time)) > '2014-12-31' and DATE(FROM_UNIXTIME(post_time)) < '2019-03-01'
# group by YEAR(FROM_UNIXTIME(post_time)), MONTH(FROM_UNIXTIME(post_time))
# order by YEAR(FROM_UNIXTIME(post_time)) desc, MONTH(FROM_UNIXTIME(post_time)) desc;

# %% [markdown]
# Create docs for the following two cases
# - exits_login, when a login ttid come to a forum and matched a existing user with same email, the ttid can not register, we ask ARE_YOU_USERNAME_IN_THIE_GROUP, and let hom log in
# - switch_forumId, a login ttid and a login forum account, but the TTID bind with another forum account, we ask do you want to switch to current forum account.

# %% [markdown]
# ### &XDEBUG_SESSION_START=
# http://hansonlocal.cc/groups/test1/index.php?XDEBUG_SESSION_START=15025
#
#
# 文字靠下面,comment最多两行,高亮图标变大,icon限制大小
#
# select p.post_id, p.topic_id, p.forum_id, p.poster_id, p.poster_ip, u.username, u.user_email, DATE_FORMAT(FROM_UNIXTIME(p.post_time), '%Y-%m-%d %H:%i:%s') as post_time, p.post_text
# from hs_myfreeforum_2.brothersistertruelove_posts p
# left join hs_myfreeforum_2.brothersistertruelove_users u on p.poster_id=u.user_id
# limit 1100;
#
#
# select DATE_FORMAT(FROM_UNIXTIME(p.message_time), '%Y-%m-%d %H:%i:%s') AS message_date, p.*, u.user_ip as author_user_ip, u.username as author_username, u.user_email as author_user_email from hs_zetaboards_2.xerux14_privmsgs p
# left join hs_zetaboards_2.xerux14_users u on p.author_id=u.user_id limit 1600;
#
#
# - pay todownload UI(hats), check gold point balance first GP_BALANCE, if sufficient, confirm.
#
# - https://www.tapatalk.com/editForum/1981405 there is no cancel for basic tier, please review the code and find the root cause with the subscription cancellation and sign up.
# - 论坛头部在 有 logo/banner,  有 description, 或者尺寸不一样的时候, 如何保持统一.考虑logo 预留一个固定区域   如果图片太小则显示在图片中间
# - post mode select UI
# - forum title,desc, view post, last poster, everything vertical align middle
# - 每月最多提现 500
# - transaction UMB8KP5PF6CTC failed, give back the gold point
#
# - editor height jumping issue
# - language datetime and timezones
# - custom domain also sign out tapatalk.com
# - code/phpbb/avatar/driver/upload.php line 249
# - background image height not extend to wrap
# - remove theme color css except .tapatalk-theme-
# - ttg cookie  forum_status
# - whenever focus on a input or textarea, border same as them color
# - stripe connection check contry, if not US, ask for paypal, get the wording from Howdy
# - remove donation redis, get recent donation history from ttg_goldpoint_history
# - logout clear cookie, maintain a cookie white list
# - 中文的字体变小
# - TTID deactivate 之后，隐藏链接部分在ACP
# - 登录TTID 然后， 在论坛里发现邮箱一样的账号，如果这个账号已经链接到了另一个TTID名下， 这时候不要推荐
# - validate css and compress HTML
# - check emails
# - banned TTID should also be banned in forum
# - 编辑器 @ 一个人之后 变成了 黑色字体
# - on ipads, editor covered 1/3 of the bottom text
#
#
# # test redis performance for FU_TT/TT_FU
# # EMOTION 有很大的优化空间
#
#
#
# - remove recaptcha in forum register
# - user s shall only see the ttid_welcome page once only
#
# - donation pending message
# - 绑定 stripe 的地方，如果不在一个区域，提示他输入 PayPal 邮箱
#
# - display UNCLAIMED             description: VGA compatible controller
# - find invite on register close forums
# - 一个月一次的提醒用户绑定 ttid 的逻辑
# - force ttid login the app 部分
# - 8) I can post on the forum without confirming the email on my TTID. I just created a TTID and connected it to an old forum account. I can post without activating the TTID email.
# this issue is not fixed yet, I will send a new email to follow it.
# - csrf-token expire, send a correct error message. not only 500
#
# - 翻译 1, check box to show all untranslated  2, show English as default whiel display other language  4, hide change all   3. pagination show more, up and down
#
# - 论坛用户  未激活  但是ttid已经激活了/被办了，这个时候是否要更新邮箱？
# - 当ttid是 inactive/banned 要怎么处理？目前没做处理，认为他没有绑定
# - ａｄｍin　ａｐｐｒｏｖｅ的用户需要ａｃｔｋｅｙ吗？ main_listener line 1336
# - 当论坛账号登录了，当时登出了tapatalk.com这个时候也要提示登录
# - disable multi account when force ttid enabled
# - 从 cookie 里面取 _logintType_user_id 如果是论坛账号登录的   那么就不管   是 ttid 的就需要他必须在 tapatalk.com保持登录
# - 之前提示连接弹出一个 popup 的逻辑需要确认
# - 对于 private board 因该只显示 LOGIN 页面 当有 ttid cookie的时候
#
# 我这边测试force ttid碰到的几个问题和需求改动：
# - 从TTID登录或者注册页面返回，TTG获得TTID的session，如果没有已绑定账号，应该总是回到Login Page。
# - 用户的那个banner还没加
# - TTG的Login Page是否显示Join的逻辑有bug
# - Private TTG，如果已经获得TTID权限，不应该再显示Welcome页面。
# - Private TTG或者guest没有权限的时候，Welcome和Login page文字更新一下：
#
#
# 查一下 paypal_tier_history
#
# 不显示+-号的时候  论坛列表总是打开的
#
# 调整快捷回复左右部分位置，和上面的帖子内容对齐
#
# place quote author's name right above the content
#
# dohtml, can scroll horizontally when screen is small
#
# digishuotalk, give guests download permission
#
# find-unused-css， 删除未使用的 css
#
# 跟非没过的 stripe账户添加绑定PayPal的入口   在支付是判断stripe是否在同一个区域
#
# emoji_support 判断是不是phpbb3.2 并且 post_text 字段支持mb4
#
# 从 ttg_payment_history 过滤 Tapatalk Basic Tier Monthly Subscription - Canon-board.info
#
#
# error site cannot be installed the start url in manifest is not valid
#
# fix last poster username issue on vets
#
# attachemnt 樣式
#
# 帖子排序要记录cookie
#
# fix composer 各种奇怪的字体样式，在复制粘贴的时候
#
# 编辑器会自动加两个换行
#
# https://www.democracyforums.com to the popular forums
#
# welcome message 合并到 global ann
#
# global notification API. forumid=0. return global announcement
#
# 修复  norification avatar 的问题  全都采用 $user::getAvatarUrl()
#
# 帖子下面的一排按钮要永远靠下
#
# summerize css rules
#
# fix post signature links open in a new tab
#
# fix litemode keys change issue, scriptname=index
#
# guest like
#
# 首页new topic jump box对于locked forum admin是可以发帖的
#
# 写一个方法，获取用户是否可以在某一个论坛发帖，放在user对象中，在首页的jumpbox调用
#
# timezone  cookie记录了两遍，在论坛根目录和/discussion目录下
#
# 检查官网首页 /home 的数据库链接和redis连接，不要重复取信息
#
# 修改automod 帖子的顺序
#
# fix search route
#
# 146634 论坛连续两次购买了premium membership
#
# permission need to hide,
# - can send email
# - can change username
# - Can send instant messages
#
# # quick reply has font style, need to remove it && https://www.tapatalk.com/groups/tapatalksupport/viewtopic.php?f=98&t=40721&utm_medium=email
#
# # remove verticalAlignDD(). if there is other js functiuons that touch css, better also remove them and do good css with media queries
#
# ## https://github.com/tapatalk/tapatalk-phpbb31/issues/147
#
# # pm mark read is not working
#
# # hardlinecrawlers styles.
#
# # LOAD_USER_ACTIVITY_LIMIT
# # image link should open real link
# # share post, hilight the post postview 高亮边框
# # signature links target=_blank
# # display smart banner all the time
# # ask jagoba about the ads style on mobile
# # merge topic logic, if post time is wrong, check the logic

# %% [markdown]
#  cg admin / @Kutz!!Af7vcxutz!!Af7j7

# %%
# %%HTML
#
# <table style="border:none;border-collapse:collapse"><colgroup><col width="160"><col width="223"><col width="299"></colgroup><tbody><tr style="height:15.75pt"><td style="border-width:0.75pt;border-style:solid;border-color:rgb(204,204,204);vertical-align:bottom;background-color:rgb(255,255,255);padding:2pt"><p dir="ltr" style="line-height:1.38;margin-top:0pt;margin-bottom:0pt"><span style="font-size:11pt;font-family:Arial;color:rgb(0,0,0);background-color:transparent;font-weight:400;font-style:normal;font-variant:normal;text-decoration:none;vertical-align:baseline;white-space:pre-wrap">Site</span></p></td><td style="border-width:0.75pt;border-style:solid;border-color:rgb(204,204,204);vertical-align:bottom;background-color:rgb(255,255,255);padding:2pt"><p dir="ltr" style="line-height:1.38;margin-top:0pt;margin-bottom:0pt"><span style="font-size:11pt;font-family:Arial;color:rgb(0,0,0);background-color:transparent;font-weight:400;font-style:normal;font-variant:normal;text-decoration:none;vertical-align:baseline;white-space:pre-wrap">pw</span></p></td><td style="border-width:0.75pt;border-style:solid;border-color:rgb(204,204,204);vertical-align:bottom;background-color:rgb(255,255,255);padding:2pt"><p dir="ltr" style="line-height:1.38;margin-top:0pt;margin-bottom:0pt"><span style="font-size:11pt;font-family:Arial;color:rgb(0,0,0);background-color:transparent;font-weight:400;font-style:normal;font-variant:normal;text-decoration:none;vertical-align:baseline;white-space:pre-wrap">comments</span></p></td></tr><tr style="height:15.75pt"><td style="border-width:0.75pt;border-style:solid;border-color:rgb(204,204,204);vertical-align:bottom;background-color:rgb(255,255,255);padding:2pt"><p dir="ltr" style="line-height:1.38;margin-top:0pt;margin-bottom:0pt"><a href="http://zealot.com/" style="text-decoration:none" target="_blank" data-saferedirecturl="https://www.google.com/url?q=http://zealot.com/&amp;source=gmail&amp;ust=1537498404434000&amp;usg=AFQjCNGDU4k0FmTAJHQMpakI2pDmiCTB9Q"><span style="font-size:11pt;font-family:Arial;color:rgb(17,85,204);background-color:transparent;font-weight:400;font-style:normal;font-variant:normal;text-decoration:underline;vertical-align:baseline;white-space:pre-wrap">Zealot.com</span></a></p><br></td><td style="border-width:0.75pt;border-style:solid;border-color:rgb(204,204,204);vertical-align:bottom;background-color:rgb(255,255,255);padding:2pt"><p dir="ltr" style="line-height:1.38;margin-top:0pt;margin-bottom:0pt"><span style="font-size:11pt;font-family:Arial;color:rgb(0,0,0);background-color:transparent;font-weight:400;font-style:normal;font-variant:normal;text-decoration:none;vertical-align:baseline;white-space:pre-wrap">Hna4Wpwgkp4Wpe$8@28</span></p></td><td style="border-width:0.75pt;border-style:solid;border-color:rgb(204,204,204);vertical-align:bottom;background-color:rgb(255,255,255);padding:2pt"><p dir="ltr" style="line-height:1.38;margin-top:0pt;margin-bottom:0pt"><span style="font-size:11pt;font-family:Arial;color:rgb(0,0,0);background-color:transparent;font-weight:400;font-style:normal;font-variant:normal;text-decoration:none;vertical-align:baseline;white-space:pre-wrap">The forum has xengallery plugin. It would be comparable to what we will have at TTG. Do not migrate without gallery, admin will have a cow. </span></p></td></tr><tr style="height:15.75pt"><td style="border-width:0.75pt;border-style:solid;border-color:rgb(204,204,204);vertical-align:bottom;background-color:rgb(255,255,255);padding:2pt"><p dir="ltr" style="line-height:1.38;margin-top:0pt;margin-bottom:0pt"><a href="http://writers.net/" style="text-decoration:none" target="_blank" data-saferedirecturl="https://www.google.com/url?q=http://writers.net/&amp;source=gmail&amp;ust=1537498404434000&amp;usg=AFQjCNEJrsnOsyF3nG518116q6dWyqkqDQ"><span style="font-size:11pt;font-family:Arial;color:rgb(17,85,204);background-color:transparent;font-weight:400;font-style:normal;font-variant:normal;text-decoration:underline;vertical-align:baseline;white-space:pre-wrap">writers.net</span></a></p></td><td style="border-width:0.75pt;border-style:solid;border-color:rgb(204,204,204);vertical-align:bottom;background-color:rgb(255,255,255);padding:2pt"><p dir="ltr" style="line-height:1.38;margin-top:0pt;margin-bottom:0pt"><span style="font-size:11pt;font-family:Arial;color:rgb(0,0,0);background-color:transparent;font-weight:400;font-style:normal;font-variant:normal;text-decoration:none;vertical-align:baseline;white-space:pre-wrap">J6X8dHudpfazjs</span></p></td><td style="border-width:0.75pt;border-style:solid;border-color:rgb(204,204,204);vertical-align:bottom;background-color:rgb(255,255,255);padding:2pt"><p dir="ltr" style="line-height:1.38;margin-top:0pt;margin-bottom:0pt"><span style="font-size:11pt;font-family:Arial;color:rgb(0,0,0);background-color:transparent;font-weight:400;font-style:normal;font-variant:normal;text-decoration:none;vertical-align:baseline;white-space:pre-wrap">The forum itself is inactive. The site has a huge resource center, which gets most of the traffic. If you want any traffic, you’d need to find a way to keep the forum associated with the resource center. Of all CG hosted sites, <a href="http://writers.net" target="_blank" data-saferedirecturl="https://www.google.com/url?q=http://writers.net&amp;source=gmail&amp;ust=1537498404434000&amp;usg=AFQjCNG13mEZT1rBT9vUDBPo4HY_Q2qLkQ">writers.net</a> had the highest revenue due to the resource center.</span></p></td></tr><tr style="height:15.75pt"><td style="border-width:0.75pt;border-style:solid;border-color:rgb(204,204,204);vertical-align:bottom;background-color:rgb(255,255,255);padding:2pt"><p dir="ltr" style="line-height:1.38;margin-top:0pt;margin-bottom:0pt"><a href="http://genmay.com/" style="text-decoration:none" target="_blank" data-saferedirecturl="https://www.google.com/url?q=http://genmay.com/&amp;source=gmail&amp;ust=1537498404434000&amp;usg=AFQjCNEGf0zE0gKIBasSJjLL4GWsWC4C9g"><span style="font-size:11pt;font-family:Arial;color:rgb(17,85,204);background-color:transparent;font-weight:400;font-style:normal;font-variant:normal;text-decoration:underline;vertical-align:baseline;white-space:pre-wrap">genmay.com</span></a></p></td><td style="border-width:0.75pt;border-style:solid;border-color:rgb(204,204,204);vertical-align:bottom;background-color:rgb(255,255,255);padding:2pt"><p dir="ltr" style="line-height:1.38;margin-top:0pt;margin-bottom:0pt"><span style="font-size:11pt;font-family:Arial;color:rgb(0,0,0);background-color:transparent;font-weight:400;font-style:normal;font-variant:normal;text-decoration:none;vertical-align:baseline;white-space:pre-wrap">MNYXcUvBCHd83BXLtur</span></p></td><td style="border-width:0.75pt;border-style:solid;border-color:rgb(204,204,204);vertical-align:bottom;background-color:rgb(255,255,255);padding:2pt"><p dir="ltr" style="line-height:1.38;margin-top:0pt;margin-bottom:0pt"><span style="font-size:11pt;font-family:Arial;color:rgb(0,0,0);background-color:transparent;font-weight:400;font-style:normal;font-variant:normal;text-decoration:none;vertical-align:baseline;white-space:pre-wrap">This forum was once very busy, but is now barely active. If you put ads on this one, you’d run a serious risk to be banned by the advertisers. The language on the forum is very rude and vulgar. If you browse around for only a few minutes there, you’ll know what I mean. It’s a liability and would definitely have to be marked NSFW</span></p></td></tr><tr style="height:15.75pt"><td style="border-width:0.75pt;border-style:solid;border-color:rgb(204,204,204);vertical-align:bottom;background-color:rgb(255,255,255);padding:2pt"><p dir="ltr" style="line-height:1.38;margin-top:0pt;margin-bottom:0pt"><a href="http://nsider2.com/" style="text-decoration:none" target="_blank" data-saferedirecturl="https://www.google.com/url?q=http://nsider2.com/&amp;source=gmail&amp;ust=1537498404434000&amp;usg=AFQjCNHtAV5rlqcQOa9WqVqdZOgUwmuSNA"><span style="font-size:11pt;font-family:Arial;color:rgb(17,85,204);background-color:transparent;font-weight:400;font-style:normal;font-variant:normal;text-decoration:underline;vertical-align:baseline;white-space:pre-wrap">nsider2.com</span></a></p></td><td style="border-width:0.75pt;border-style:solid;border-color:rgb(204,204,204);vertical-align:bottom;background-color:rgb(255,255,255);padding:2pt"><p dir="ltr" style="line-height:1.38;margin-top:0pt;margin-bottom:0pt"><span style="font-size:11pt;font-family:Arial;color:rgb(0,0,0);background-color:transparent;font-weight:400;font-style:normal;font-variant:normal;text-decoration:none;vertical-align:baseline;white-space:pre-wrap">557f63f5946ce5f</span></p></td><td style="border-width:0.75pt;border-style:solid;border-color:rgb(204,204,204);vertical-align:bottom;background-color:rgb(255,255,255);padding:2pt"><p dir="ltr" style="line-height:1.38;margin-top:0pt;margin-bottom:0pt"><span style="font-size:11pt;font-family:Arial;color:rgb(0,0,0);background-color:transparent;font-weight:400;font-style:normal;font-variant:normal;text-decoration:none;vertical-align:baseline;white-space:pre-wrap">IPB. Has wordpress plugin. Forum is completely dead. Admin went rogue, started his own forum and took all the members with him. Until this happened, the forum was quite busy. It went completely dead overnight.</span></p></td></tr><tr style="height:15.75pt"><td style="border-width:0.75pt;border-style:solid;border-color:rgb(204,204,204);vertical-align:bottom;background-color:rgb(255,255,255);padding:2pt"><p dir="ltr" style="line-height:1.38;margin-top:0pt;margin-bottom:0pt"><a href="http://wiispace.com/" style="text-decoration:none" target="_blank" data-saferedirecturl="https://www.google.com/url?q=http://wiispace.com/&amp;source=gmail&amp;ust=1537498404434000&amp;usg=AFQjCNE--4rMFYRQ_vN9FtCu_KjkuX2YRw"><span style="font-size:11pt;font-family:Arial;color:rgb(17,85,204);background-color:transparent;font-weight:400;font-style:normal;font-variant:normal;text-decoration:underline;vertical-align:baseline;white-space:pre-wrap">wiispace.com</span></a></p></td><td style="border-width:0.75pt;border-style:solid;border-color:rgb(204,204,204);vertical-align:bottom;background-color:rgb(255,255,255);padding:2pt"><p dir="ltr" style="line-height:1.38;margin-top:0pt;margin-bottom:0pt"><span style="font-size:11pt;font-family:Arial;color:rgb(0,0,0);background-color:transparent;font-weight:400;font-style:normal;font-variant:normal;text-decoration:none;vertical-align:baseline;white-space:pre-wrap">qt%batonwskklptonble*</span></p></td><td style="border-width:0.75pt;border-style:solid;border-color:rgb(204,204,204);vertical-align:bottom;background-color:rgb(255,255,255);padding:2pt"><p dir="ltr" style="line-height:1.38;margin-top:0pt;margin-bottom:0pt"><span style="font-size:11pt;font-family:Arial;color:rgb(0,0,0);background-color:transparent;font-weight:400;font-style:normal;font-variant:normal;text-decoration:none;vertical-align:baseline;white-space:pre-wrap">This forum has been dead for years.</span></p></td></tr><tr style="height:15.75pt"><td style="border-width:0.75pt;border-style:solid;border-color:rgb(204,204,204);vertical-align:bottom;background-color:rgb(255,255,255);padding:2pt"><p dir="ltr" style="line-height:1.38;margin-top:0pt;margin-bottom:0pt"><a href="http://digishoptalk.com/" style="text-decoration:none" target="_blank" data-saferedirecturl="https://www.google.com/url?q=http://digishoptalk.com/&amp;source=gmail&amp;ust=1537498404434000&amp;usg=AFQjCNEzzxSWNFnDU_j25mQtDbqRncE0tQ"><span style="font-size:11pt;font-family:Arial;color:rgb(17,85,204);background-color:transparent;font-weight:400;font-style:normal;font-variant:normal;text-decoration:underline;vertical-align:baseline;white-space:pre-wrap">digishoptalk.com</span></a></p></td><td style="border-width:0.75pt;border-style:solid;border-color:rgb(204,204,204);vertical-align:bottom;background-color:rgb(255,255,255);padding:2pt"><p dir="ltr" style="line-height:1.38;margin-top:0pt;margin-bottom:0pt"><span style="font-size:11pt;font-family:Arial;color:rgb(0,0,0);background-color:transparent;font-weight:400;font-style:normal;font-variant:normal;text-decoration:none;vertical-align:baseline;white-space:pre-wrap">28y7$dJ4mkqadJ4QueD</span></p></td><td style="border-width:0.75pt;border-style:solid;border-color:rgb(204,204,204);vertical-align:bottom;background-color:rgb(255,255,255);padding:2pt"><p dir="ltr" style="line-height:1.38;margin-top:0pt;margin-bottom:0pt"><span style="font-size:11pt;font-family:Arial;color:rgb(0,0,0);background-color:transparent;font-weight:400;font-style:normal;font-variant:normal;text-decoration:none;vertical-align:baseline;white-space:pre-wrap">Forum cannot exist without the galleries. There are two galleries, a product and a layout gallery. Members upload their products to the product gallery (they have to pay for that) and the layout gallery is where members upload things after they make them with the products from the product gallery. The forum has several paid membership levels. I don’t know enough about the galleries to determine whether our own gallery would be compatible, but I know whom to ask. Should know complete details on the galleries in the next day or so.</span></p></td></tr><tr style="height:15.75pt"><td style="border-width:0.75pt;border-style:solid;border-color:rgb(204,204,204);vertical-align:bottom;background-color:rgb(255,255,255);padding:2pt"><p dir="ltr" style="line-height:1.38;margin-top:0pt;margin-bottom:0pt"><a href="http://www.fishtankforums.com/forum.php" style="text-decoration:none" target="_blank" data-saferedirecturl="https://www.google.com/url?q=http://www.fishtankforums.com/forum.php&amp;source=gmail&amp;ust=1537498404434000&amp;usg=AFQjCNHCWiAZyUG_IrTRxVtVYsWlXZzwag"><span style="font-size:11pt;font-family:Arial;color:rgb(17,85,204);background-color:transparent;font-weight:400;font-style:normal;font-variant:normal;text-decoration:underline;vertical-align:baseline;white-space:pre-wrap">http://www.fishtankforums.com/<wbr>forum.php</span></a></p></td><td style="border-width:0.75pt;border-style:solid;border-color:rgb(204,204,204);vertical-align:bottom;background-color:rgb(255,255,255);padding:2pt"><p dir="ltr" style="line-height:1.38;margin-top:0pt;margin-bottom:0pt"><span style="font-size:11pt;font-family:Arial;color:rgb(0,0,0);background-color:transparent;font-weight:400;font-style:normal;font-variant:normal;text-decoration:none;vertical-align:baseline;white-space:pre-wrap">f9*qNR6hCvbty6hCNK3</span></p></td><td style="border-width:0.75pt;border-style:solid;border-color:rgb(204,204,204);vertical-align:bottom;background-color:rgb(255,255,255);padding:2pt"><p dir="ltr" style="line-height:1.38;margin-top:0pt;margin-bottom:0pt"><span style="font-size:11pt;font-family:Arial;color:rgb(0,0,0);background-color:transparent;font-weight:400;font-style:normal;font-variant:normal;text-decoration:none;vertical-align:baseline;white-space:pre-wrap">Forum has been dead for years.</span></p></td></tr><tr style="height:15.75pt"><td style="border-width:0.75pt;border-style:solid;border-color:rgb(204,204,204);vertical-align:bottom;background-color:rgb(255,255,255);padding:2pt"><p dir="ltr" style="line-height:1.38;margin-top:0pt;margin-bottom:0pt"><a href="http://writersbeat.com/" style="text-decoration:none" target="_blank" data-saferedirecturl="https://www.google.com/url?q=http://writersbeat.com/&amp;source=gmail&amp;ust=1537498404434000&amp;usg=AFQjCNGiCHfS1TgwKxo5yhEeeVwPO0b8DQ"><span style="font-size:11pt;font-family:Arial;color:rgb(17,85,204);background-color:transparent;font-weight:400;font-style:normal;font-variant:normal;text-decoration:underline;vertical-align:baseline;white-space:pre-wrap">writersbeat.com</span></a></p></td><td style="border-width:0.75pt;border-style:solid;border-color:rgb(204,204,204);vertical-align:bottom;background-color:rgb(255,255,255);padding:2pt"><p dir="ltr" style="line-height:1.38;margin-top:0pt;margin-bottom:0pt"><span style="font-size:11pt;font-family:Arial;color:rgb(0,0,0);background-color:transparent;font-weight:400;font-style:normal;font-variant:normal;text-decoration:none;vertical-align:baseline;white-space:pre-wrap">4Z!4H6y47BZ!4H6ypp</span></p></td><td style="border-width:0.75pt;border-style:solid;border-color:rgb(204,204,204);vertical-align:bottom;background-color:rgb(255,255,255);padding:2pt"><p dir="ltr" style="line-height:1.38;margin-top:0pt;margin-bottom:0pt"><span style="font-size:11pt;font-family:Arial;color:rgb(0,0,0);background-color:transparent;font-weight:400;font-style:normal;font-variant:normal;text-decoration:none;vertical-align:baseline;white-space:pre-wrap">Not a bad forum, and it has daily activity.</span></p></td></tr><tr style="height:15.75pt"><td style="border-width:0.75pt;border-style:solid;border-color:rgb(204,204,204);vertical-align:bottom;background-color:rgb(255,255,255);padding:2pt"><p dir="ltr" style="line-height:1.38;margin-top:0pt;margin-bottom:0pt"><a href="http://zuneboards.com/" style="text-decoration:none" target="_blank" data-saferedirecturl="https://www.google.com/url?q=http://zuneboards.com/&amp;source=gmail&amp;ust=1537498404434000&amp;usg=AFQjCNGEFM4WS3-CrYGj7HBhC_2d4oMkcQ"><span style="font-size:11pt;font-family:Arial;color:rgb(17,85,204);background-color:transparent;font-weight:400;font-style:normal;font-variant:normal;text-decoration:underline;vertical-align:baseline;white-space:pre-wrap">zuneboards.com</span></a></p></td><td style="border-width:0.75pt;border-style:solid;border-color:rgb(204,204,204);vertical-align:bottom;background-color:rgb(255,255,255);padding:2pt"><p dir="ltr" style="line-height:1.38;margin-top:0pt;margin-bottom:0pt"><span style="font-size:11pt;font-family:Arial;color:rgb(0,0,0);background-color:transparent;font-weight:400;font-style:normal;font-variant:normal;text-decoration:none;vertical-align:baseline;white-space:pre-wrap">mv&amp;R4gxzy4gkqS55u</span></p></td><td style="border-width:0.75pt;border-style:solid;border-color:rgb(204,204,204);vertical-align:bottom;background-color:rgb(255,255,255);padding:2pt"><p dir="ltr" style="line-height:1.38;margin-top:0pt;margin-bottom:0pt"><span style="font-size:11pt;font-family:Arial;color:rgb(0,0,0);background-color:transparent;font-weight:400;font-style:normal;font-variant:normal;text-decoration:none;vertical-align:baseline;white-space:pre-wrap">Fairly dead board, it still has a post occasionally, like once a week,</span></p></td></tr><tr style="height:15.75pt"><td style="border-width:0.75pt;border-style:solid;border-color:rgb(204,204,204);vertical-align:bottom;background-color:rgb(255,255,255);padding:2pt"><p dir="ltr" style="line-height:1.38;margin-top:0pt;margin-bottom:0pt"><a href="http://www.totallyfrugal.com/forums/" style="text-decoration:none" target="_blank" data-saferedirecturl="https://www.google.com/url?q=http://www.totallyfrugal.com/forums/&amp;source=gmail&amp;ust=1537498404434000&amp;usg=AFQjCNEcWuIwFb7VKo75z59PkvLLEAgluw"><span style="font-size:11pt;font-family:Arial;color:rgb(17,85,204);background-color:transparent;font-weight:400;font-style:normal;font-variant:normal;text-decoration:underline;vertical-align:baseline;white-space:pre-wrap">http://www.totallyfrugal.com/<wbr>forums/</span></a></p></td><td style="border-width:0.75pt;border-style:solid;border-color:rgb(204,204,204);vertical-align:bottom;background-color:rgb(255,255,255);padding:2pt"><p dir="ltr" style="line-height:1.38;margin-top:0pt;margin-bottom:0pt"><span style="font-size:11pt;font-family:Arial;color:rgb(0,0,0);background-color:transparent;font-weight:400;font-style:normal;font-variant:normal;text-decoration:none;vertical-align:baseline;white-space:pre-wrap">*t6$fE#6Czxzquk#6Cz9n</span></p></td><td style="border-width:0.75pt;border-style:solid;border-color:rgb(204,204,204);vertical-align:bottom;background-color:rgb(255,255,255);padding:2pt"><p dir="ltr" style="line-height:1.38;margin-top:0pt;margin-bottom:0pt"><span style="font-size:11pt;font-family:Arial;color:rgb(0,0,0);background-color:transparent;font-weight:400;font-style:normal;font-variant:normal;text-decoration:none;vertical-align:baseline;white-space:pre-wrap">This forum has potential. It has a lot of good posts, especially the older posts. Still visited and posted at nowadays by a couple of members.</span></p></td></tr><tr style="height:15.75pt"><td style="border-width:0.75pt;border-style:solid;border-color:rgb(204,204,204);vertical-align:bottom;background-color:rgb(255,255,255);padding:2pt"><br></td><td style="border-width:0.75pt;border-style:solid;border-color:rgb(204,204,204);vertical-align:bottom;background-color:rgb(255,255,255);padding:2pt"><br></td><td style="border-width:0.75pt;border-style:solid;border-color:rgb(204,204,204);vertical-align:bottom;background-color:rgb(255,255,255);padding:2pt"><br></td></tr><tr style="height:15.75pt"><td style="border-width:0.75pt;border-style:solid;border-color:rgb(204,204,204);vertical-align:bottom;background-color:rgb(255,255,255);padding:2pt"><p dir="ltr" style="line-height:1.38;margin-top:0pt;margin-bottom:0pt"><a href="http://abxzone.com/" style="text-decoration:none" target="_blank" data-saferedirecturl="https://www.google.com/url?q=http://abxzone.com/&amp;source=gmail&amp;ust=1537498404434000&amp;usg=AFQjCNFBNBAj2ksMSZgj_Xan-rseA37HWA"><span style="font-size:11pt;font-family:Arial;color:rgb(17,85,204);background-color:transparent;font-weight:400;font-style:normal;font-variant:normal;text-decoration:underline;vertical-align:baseline;white-space:pre-wrap">abxzone.com</span></a></p></td><td style="border-width:0.75pt;border-style:solid;border-color:rgb(204,204,204);vertical-align:bottom;background-color:rgb(255,255,255);padding:2pt"><p dir="ltr" style="line-height:1.38;margin-top:0pt;margin-bottom:0pt"><span style="font-size:11pt;font-family:Arial;color:rgb(0,0,0);background-color:transparent;font-weight:400;font-style:normal;font-variant:normal;text-decoration:none;vertical-align:baseline;white-space:pre-wrap">39aQM&amp;ZH!ebmuyt&amp;ZH!eG8</span></p></td><td style="border-width:0.75pt;border-style:solid;border-color:rgb(204,204,204);vertical-align:bottom;background-color:rgb(255,255,255);padding:2pt"><p dir="ltr" style="line-height:1.38;margin-top:0pt;margin-bottom:0pt"><span style="font-size:11pt;font-family:Arial;color:rgb(0,0,0);background-color:transparent;font-weight:400;font-style:normal;font-variant:normal;text-decoration:none;vertical-align:baseline;white-space:pre-wrap">Has a few long time loyal members who are still posting.</span></p></td></tr><tr style="height:15.75pt"><td style="border-width:0.75pt;border-style:solid;border-color:rgb(204,204,204);vertical-align:bottom;background-color:rgb(255,255,255);padding:2pt"><p dir="ltr" style="line-height:1.38;margin-top:0pt;margin-bottom:0pt"><a href="http://saturnspot.com/" style="text-decoration:none" target="_blank" data-saferedirecturl="https://www.google.com/url?q=http://saturnspot.com/&amp;source=gmail&amp;ust=1537498404434000&amp;usg=AFQjCNEK0r2OlTy1pcPJ1yTn9paLf3G1Fg"><span style="font-size:11pt;font-family:Arial;color:rgb(17,85,204);background-color:transparent;font-weight:400;font-style:normal;font-variant:normal;text-decoration:underline;vertical-align:baseline;white-space:pre-wrap">saturnspot.com</span></a></p></td><td style="border-width:0.75pt;border-style:solid;border-color:rgb(204,204,204);vertical-align:bottom;background-color:rgb(255,255,255);padding:2pt"><p dir="ltr" style="line-height:1.38;margin-top:0pt;margin-bottom:0pt"><span style="font-size:11pt;font-family:Arial;color:rgb(0,0,0);background-color:transparent;font-weight:400;font-style:normal;font-variant:normal;text-decoration:none;vertical-align:baseline;white-space:pre-wrap">9$cJJuzaxxwAMc4x^z</span></p></td><td style="border-width:0.75pt;border-style:solid;border-color:rgb(204,204,204);vertical-align:bottom;background-color:rgb(255,255,255);padding:2pt"><p dir="ltr" style="line-height:1.38;margin-top:0pt;margin-bottom:0pt"><span style="font-size:11pt;font-family:Arial;color:rgb(0,0,0);background-color:transparent;font-weight:400;font-style:normal;font-variant:normal;text-decoration:none;vertical-align:baseline;white-space:pre-wrap">Inactive forum. Has an occasional post.</span></p></td></tr><tr style="height:15.75pt"><td style="border-width:0.75pt;border-style:solid;border-color:rgb(204,204,204);vertical-align:bottom;background-color:rgb(255,255,255);padding:2pt"><br></td><td style="border-width:0.75pt;border-style:solid;border-color:rgb(204,204,204);vertical-align:bottom;background-color:rgb(255,255,255);padding:2pt"><br></td><td style="border-width:0.75pt;border-style:solid;border-color:rgb(204,204,204);vertical-align:bottom;background-color:rgb(255,255,255);padding:2pt"><br></td></tr><tr style="height:15.75pt"><td style="border-width:0.75pt;border-style:solid;border-color:rgb(204,204,204);vertical-align:bottom;background-color:rgb(255,255,255);padding:2pt"><p dir="ltr" style="line-height:1.38;margin-top:0pt;margin-bottom:0pt"><a href="http://parentingforums.org/" style="text-decoration:none" target="_blank" data-saferedirecturl="https://www.google.com/url?q=http://parentingforums.org/&amp;source=gmail&amp;ust=1537498404434000&amp;usg=AFQjCNHn7pgQGVgXVOmUPGNmwxV6eisUZw"><span style="font-size:11pt;font-family:Arial;color:rgb(17,85,204);background-color:transparent;font-weight:400;font-style:normal;font-variant:normal;text-decoration:underline;vertical-align:baseline;white-space:pre-wrap">parentingforums.org</span></a></p></td><td style="border-width:0.75pt;border-style:solid;border-color:rgb(204,204,204);vertical-align:bottom;background-color:rgb(255,255,255);padding:2pt"><p dir="ltr" style="line-height:1.38;margin-top:0pt;margin-bottom:0pt"><span style="font-size:11pt;font-family:Arial;color:rgb(0,0,0);background-color:transparent;font-weight:400;font-style:normal;font-variant:normal;text-decoration:none;vertical-align:baseline;white-space:pre-wrap">t9^9zvJzxqakvJrJDG6</span></p></td><td style="border-width:0.75pt;border-style:solid;border-color:rgb(204,204,204);vertical-align:bottom;background-color:rgb(255,255,255);padding:2pt"><p dir="ltr" style="line-height:1.38;margin-top:0pt;margin-bottom:0pt"><span style="font-size:11pt;font-family:Arial;color:rgb(0,0,0);background-color:transparent;font-weight:400;font-style:normal;font-variant:normal;text-decoration:none;vertical-align:baseline;white-space:pre-wrap">This forum used to be busy but has gone inactive over time. It very rarely gets a post now.</span></p></td></tr><tr style="height:15.75pt"><td style="border-width:0.75pt;border-style:solid;border-color:rgb(204,204,204);vertical-align:bottom;background-color:rgb(255,255,255);padding:2pt"><p dir="ltr" style="line-height:1.38;margin-top:0pt;margin-bottom:0pt"><a href="http://metalthrone.net/" style="text-decoration:none" target="_blank" data-saferedirecturl="https://www.google.com/url?q=http://metalthrone.net/&amp;source=gmail&amp;ust=1537498404434000&amp;usg=AFQjCNEZJFLBNwsq-u3QQ_yuL2-x7WSkDA"><span style="font-size:11pt;font-family:Arial;color:rgb(17,85,204);background-color:transparent;font-weight:400;font-style:normal;font-variant:normal;text-decoration:underline;vertical-align:baseline;white-space:pre-wrap">metalthrone.net</span></a></p></td><td style="border-width:0.75pt;border-style:solid;border-color:rgb(204,204,204);vertical-align:bottom;background-color:rgb(255,255,255);padding:2pt"><p dir="ltr" style="line-height:1.38;margin-top:0pt;margin-bottom:0pt"><span style="font-size:11pt;font-family:Arial;color:rgb(0,0,0);background-color:transparent;font-weight:400;font-style:normal;font-variant:normal;text-decoration:none;vertical-align:baseline;white-space:pre-wrap">Q&amp;56^Nzaqpfcqmz2R</span></p></td><td style="border-width:0.75pt;border-style:solid;border-color:rgb(204,204,204);vertical-align:bottom;background-color:rgb(255,255,255);padding:2pt"><p dir="ltr" style="line-height:1.38;margin-top:0pt;margin-bottom:0pt"><span style="font-size:11pt;font-family:Arial;color:rgb(0,0,0);background-color:transparent;font-weight:400;font-style:normal;font-variant:normal;text-decoration:none;vertical-align:baseline;white-space:pre-wrap">This forum has some activity. It does have a NSFW section in plain view which would need to be hidden for sure.</span></p></td></tr><tr style="height:15.75pt"><td style="border-width:0.75pt;border-style:solid;border-color:rgb(204,204,204);vertical-align:bottom;background-color:rgb(255,255,255);padding:2pt"><p dir="ltr" style="line-height:1.38;margin-top:0pt;margin-bottom:0pt"><a href="http://talkvideogames.com/" style="text-decoration:none" target="_blank" data-saferedirecturl="https://www.google.com/url?q=http://talkvideogames.com/&amp;source=gmail&amp;ust=1537498404434000&amp;usg=AFQjCNHcm6ZwMn6RMKJzsrvXZh6swABfkw"><span style="font-size:11pt;font-family:Arial;color:rgb(17,85,204);background-color:transparent;font-weight:400;font-style:normal;font-variant:normal;text-decoration:underline;vertical-align:baseline;white-space:pre-wrap">talkvideogames.com</span></a></p></td><td style="border-width:0.75pt;border-style:solid;border-color:rgb(204,204,204);vertical-align:bottom;background-color:rgb(255,255,255);padding:2pt"><p dir="ltr" style="line-height:1.38;margin-top:0pt;margin-bottom:0pt"><span style="font-size:11pt;font-family:Arial;color:rgb(0,0,0);background-color:transparent;font-weight:400;font-style:normal;font-variant:normal;text-decoration:none;vertical-align:baseline;white-space:pre-wrap">!e75dx!VHszxwtgfHu8N</span></p></td><td style="border-width:0.75pt;border-style:solid;border-color:rgb(204,204,204);vertical-align:bottom;background-color:rgb(255,255,255);padding:2pt"><p dir="ltr" style="line-height:1.38;margin-top:0pt;margin-bottom:0pt"><span style="font-size:11pt;font-family:Arial;color:rgb(0,0,0);background-color:transparent;font-weight:400;font-style:normal;font-variant:normal;text-decoration:none;vertical-align:baseline;white-space:pre-wrap">Forum has been inactive for years.</span></p></td></tr><tr style="height:39pt"><td style="border-width:0.75pt;border-style:solid;border-color:rgb(204,204,204);vertical-align:bottom;background-color:rgb(255,255,255);padding:2pt"><p dir="ltr" style="line-height:1.38;margin-top:0pt;margin-bottom:0pt"><a href="http://sneakertalk.com/" style="text-decoration:none" target="_blank" data-saferedirecturl="https://www.google.com/url?q=http://sneakertalk.com/&amp;source=gmail&amp;ust=1537498404434000&amp;usg=AFQjCNHl1eul7bUnklwiNIqiw1adRkmboQ"><span style="font-size:11pt;font-family:Arial;color:rgb(17,85,204);background-color:transparent;font-weight:400;font-style:normal;font-variant:normal;text-decoration:underline;vertical-align:baseline;white-space:pre-wrap">sneakertalk.com</span></a></p></td><td style="border-width:0.75pt;border-style:solid;border-color:rgb(204,204,204);vertical-align:bottom;background-color:rgb(255,255,255);padding:2pt"><br></td><td style="border-width:0.75pt;border-style:solid;border-color:rgb(204,204,204);vertical-align:bottom;background-color:rgb(255,255,255);padding:2pt"><p dir="ltr" style="line-height:1.38;margin-top:0pt;margin-bottom:0pt"><span style="font-size:11pt;font-family:Arial;color:rgb(0,0,0);background-color:transparent;font-weight:400;font-style:normal;font-variant:normal;text-decoration:none;vertical-align:baseline;white-space:pre-wrap">The forum is at TTG already. Used to be the biggest forum on Yuku.</span></p></td></tr><tr style="height:15.75pt"><td style="border-width:0.75pt;border-style:solid;border-color:rgb(204,204,204);vertical-align:bottom;background-color:rgb(255,255,255);padding:2pt"><p dir="ltr" style="line-height:1.38;margin-top:0pt;margin-bottom:0pt"><a href="http://adminfusion.com/" style="text-decoration:none" target="_blank" data-saferedirecturl="https://www.google.com/url?q=http://adminfusion.com/&amp;source=gmail&amp;ust=1537498404434000&amp;usg=AFQjCNFJPOiPnanYMmIdeoh55jwc5n8aZw"><span style="font-size:11pt;font-family:Arial;color:rgb(17,85,204);background-color:transparent;font-weight:400;font-style:normal;font-variant:normal;text-decoration:underline;vertical-align:baseline;white-space:pre-wrap">adminfusion.com</span></a></p></td><td style="border-width:0.75pt;border-style:solid;border-color:rgb(204,204,204);vertical-align:bottom;background-color:rgb(255,255,255);padding:2pt"><p dir="ltr" style="line-height:1.38;margin-top:0pt;margin-bottom:0pt"><span style="font-size:11pt;font-family:Arial;color:rgb(0,0,0);background-color:transparent;font-weight:400;font-style:normal;font-variant:normal;text-decoration:none;vertical-align:baseline;white-space:pre-wrap">dL8xZGMF43daa8xZGMF</span></p></td><td style="border-width:0.75pt;border-style:solid;border-color:rgb(204,204,204);vertical-align:bottom;background-color:rgb(255,255,255);padding:2pt"><p dir="ltr" style="line-height:1.38;margin-top:0pt;margin-bottom:0pt"><span style="font-size:11pt;font-family:Arial;color:rgb(0,0,0);background-color:transparent;font-weight:400;font-style:normal;font-variant:normal;text-decoration:none;vertical-align:baseline;white-space:pre-wrap">Forum is as dead as can be, though I think it has potential. It has all kinds of plugins, but they’re all redundant since the forum is dead anyway. It still has some views.</span></p></td></tr><tr style="height:15.75pt"><td style="border-width:0.75pt;border-style:solid;border-color:rgb(204,204,204);vertical-align:bottom;background-color:rgb(255,255,255);padding:2pt"><p dir="ltr" style="line-height:1.38;margin-top:0pt;margin-bottom:0pt"><a href="http://clubconspiracy.com/" style="text-decoration:none" target="_blank" data-saferedirecturl="https://www.google.com/url?q=http://clubconspiracy.com/&amp;source=gmail&amp;ust=1537498404434000&amp;usg=AFQjCNGN1HHcRanxmE1FTmLjc3iORotT_g"><span style="font-size:11pt;font-family:Arial;color:rgb(17,85,204);background-color:transparent;font-weight:400;font-style:normal;font-variant:normal;text-decoration:underline;vertical-align:baseline;white-space:pre-wrap">clubconspiracy.com</span></a></p></td><td style="border-width:0.75pt;border-style:solid;border-color:rgb(204,204,204);vertical-align:bottom;background-color:rgb(255,255,255);padding:2pt"><p dir="ltr" style="line-height:1.38;margin-top:0pt;margin-bottom:0pt"><span style="font-size:11pt;font-family:Arial;color:rgb(0,0,0);background-color:transparent;font-weight:400;font-style:normal;font-variant:normal;text-decoration:none;vertical-align:baseline;white-space:pre-wrap">Td3VG4K47*HkxzwwtK47*Hk</span></p></td><td style="border-width:0.75pt;border-style:solid;border-color:rgb(204,204,204);vertical-align:bottom;background-color:rgb(255,255,255);padding:2pt"><p dir="ltr" style="line-height:1.38;margin-top:0pt;margin-bottom:0pt"><span style="font-size:11pt;font-family:Arial;color:rgb(0,0,0);background-color:transparent;font-weight:400;font-style:normal;font-variant:normal;text-decoration:none;vertical-align:baseline;white-space:pre-wrap">This forum still has occasional posts, mostly by the same people. It actually does have quite some data.</span></p></td></tr><tr style="height:15.75pt"><td style="border-width:0.75pt;border-style:solid;border-color:rgb(204,204,204);vertical-align:bottom;background-color:rgb(255,255,255);padding:2pt"><p dir="ltr" style="line-height:1.38;margin-top:0pt;margin-bottom:0pt"><a href="http://s2000forums.com/" style="text-decoration:none" target="_blank" data-saferedirecturl="https://www.google.com/url?q=http://s2000forums.com/&amp;source=gmail&amp;ust=1537498404434000&amp;usg=AFQjCNHQyQ-wfRjuH5zlcZ9oIe7AbWjUjA"><span style="font-size:11pt;font-family:Arial;color:rgb(17,85,204);background-color:transparent;font-weight:400;font-style:normal;font-variant:normal;text-decoration:underline;vertical-align:baseline;white-space:pre-wrap">s2000forums.com</span></a></p></td><td style="border-width:0.75pt;border-style:solid;border-color:rgb(204,204,204);vertical-align:bottom;background-color:rgb(255,255,255);padding:2pt"><p dir="ltr" style="line-height:1.38;margin-top:0pt;margin-bottom:0pt"><span style="font-size:11pt;font-family:Arial;color:rgb(0,0,0);background-color:transparent;font-weight:400;font-style:normal;font-variant:normal;text-decoration:none;vertical-align:baseline;white-space:pre-wrap">0Ubteqip9mm32Wr12ncvx</span></p></td><td style="border-width:0.75pt;border-style:solid;border-color:rgb(204,204,204);vertical-align:bottom;background-color:rgb(255,255,255);padding:2pt"><p dir="ltr" style="line-height:1.38;margin-top:0pt;margin-bottom:0pt"><span style="font-size:11pt;font-family:Arial;color:rgb(0,0,0);background-color:transparent;font-weight:400;font-style:normal;font-variant:normal;text-decoration:none;vertical-align:baseline;white-space:pre-wrap">Has been abandoned and inactive for years.</span></p></td></tr><tr style="height:15.75pt"><td style="border-width:0.75pt;border-style:solid;border-color:rgb(204,204,204);vertical-align:bottom;background-color:rgb(255,255,255);padding:2pt"><p dir="ltr" style="line-height:1.38;margin-top:0pt;margin-bottom:0pt"><a href="http://darkforum.com/" style="text-decoration:none" target="_blank" data-saferedirecturl="https://www.google.com/url?q=http://darkforum.com/&amp;source=gmail&amp;ust=1537498404434000&amp;usg=AFQjCNEb5fuRHzJtIL9Gvns5et_A96NFYQ"><span style="font-size:11pt;font-family:Arial;color:rgb(17,85,204);background-color:transparent;font-weight:400;font-style:normal;font-variant:normal;text-decoration:underline;vertical-align:baseline;white-space:pre-wrap">darkforum.com</span></a></p></td><td style="border-width:0.75pt;border-style:solid;border-color:rgb(204,204,204);vertical-align:bottom;background-color:rgb(255,255,255);padding:2pt"><p dir="ltr" style="line-height:1.38;margin-top:0pt;margin-bottom:0pt"><span style="font-size:11pt;font-family:Arial;color:rgb(0,0,0);background-color:transparent;font-weight:400;font-style:normal;font-variant:normal;text-decoration:none;vertical-align:baseline;white-space:pre-wrap">4KaYwdm$54daYwdmU</span></p></td><td style="border-width:0.75pt;border-style:solid;border-color:rgb(204,204,204);vertical-align:bottom;background-color:rgb(255,255,255);padding:2pt"><p dir="ltr" style="line-height:1.38;margin-top:0pt;margin-bottom:0pt"><span style="font-size:11pt;font-family:Arial;color:rgb(0,0,0);background-color:transparent;font-weight:400;font-style:normal;font-variant:normal;text-decoration:none;vertical-align:baseline;white-space:pre-wrap">Slow, with some activity, always by the same members.</span></p></td></tr><tr style="height:15.75pt"><td style="border-width:0.75pt;border-style:solid;border-color:rgb(204,204,204);vertical-align:bottom;background-color:rgb(255,255,255);padding:2pt"><p dir="ltr" style="line-height:1.38;margin-top:0pt;margin-bottom:0pt"><a href="http://cgstatic.com/" style="text-decoration:none" target="_blank" data-saferedirecturl="https://www.google.com/url?q=http://cgstatic.com/&amp;source=gmail&amp;ust=1537498404434000&amp;usg=AFQjCNHwZb1AgXbAl2XGwlDiZL9zStdSuA"><span style="font-size:11pt;font-family:Arial;color:rgb(17,85,204);background-color:transparent;font-weight:400;font-style:normal;font-variant:normal;text-decoration:underline;vertical-align:baseline;white-space:pre-wrap">cgstatic.com</span></a></p></td><td style="border-width:0.75pt;border-style:solid;border-color:rgb(204,204,204);vertical-align:bottom;background-color:rgb(255,255,255);padding:2pt"><br></td><td style="border-width:0.75pt;border-style:solid;border-color:rgb(204,204,204);vertical-align:bottom;background-color:rgb(255,255,255);padding:2pt"><p dir="ltr" style="line-height:1.38;margin-top:0pt;margin-bottom:0pt"><span style="font-size:11pt;font-family:Arial;color:rgb(0,0,0);background-color:transparent;font-weight:400;font-style:normal;font-variant:normal;text-decoration:none;vertical-align:baseline;white-space:pre-wrap">This is not a forum.</span></p></td></tr><tr style="height:15.75pt"><td style="border-width:0.75pt;border-style:solid;border-color:rgb(204,204,204);vertical-align:bottom;background-color:rgb(255,255,255);padding:2pt"><p dir="ltr" style="line-height:1.38;margin-top:0pt;margin-bottom:0pt"><a href="http://democracyforums.com/" style="text-decoration:none" target="_blank" data-saferedirecturl="https://www.google.com/url?q=http://democracyforums.com/&amp;source=gmail&amp;ust=1537498404434000&amp;usg=AFQjCNGaq-PRFZDHhptMIirZv2DlAQIdeg"><span style="font-size:11pt;font-family:Arial;color:rgb(17,85,204);background-color:transparent;font-weight:400;font-style:normal;font-variant:normal;text-decoration:underline;vertical-align:baseline;white-space:pre-wrap">democracyforums.com</span></a></p></td><td style="border-width:0.75pt;border-style:solid;border-color:rgb(204,204,204);vertical-align:bottom;background-color:rgb(255,255,255);padding:2pt"><p dir="ltr" style="line-height:1.38;margin-top:0pt;margin-bottom:0pt"><span style="font-size:11pt;font-family:Arial;color:rgb(0,0,0);background-color:transparent;font-weight:400;font-style:normal;font-variant:normal;text-decoration:none;vertical-align:baseline;white-space:pre-wrap">$d4XqNF6eE*d$d4X</span></p></td><td style="border-width:0.75pt;border-style:solid;border-color:rgb(204,204,204);vertical-align:bottom;background-color:rgb(255,255,255);padding:2pt"><p dir="ltr" style="line-height:1.38;margin-top:0pt;margin-bottom:0pt"><span style="font-size:11pt;font-family:Arial;color:rgb(0,0,0);background-color:transparent;font-weight:400;font-style:normal;font-variant:normal;text-decoration:none;vertical-align:baseline;white-space:pre-wrap">Active forum, has a handful of daily posts.</span></p></td></tr><tr style="height:15.75pt"><td style="border-width:0.75pt;border-style:solid;border-color:rgb(204,204,204);vertical-align:bottom;background-color:rgb(255,255,255);padding:2pt"><br></td><td style="border-width:0.75pt;border-style:solid;border-color:rgb(204,204,204);vertical-align:bottom;background-color:rgb(255,255,255);padding:2pt"><br></td><td style="border-width:0.75pt;border-style:solid;border-color:rgb(204,204,204);vertical-align:bottom;background-color:rgb(255,255,255);padding:2pt"><br></td></tr><tr style="height:15.75pt"><td style="border-width:0.75pt;border-style:solid;border-color:rgb(204,204,204);vertical-align:bottom;background-color:rgb(255,255,255);padding:2pt"><br></td><td style="border-width:0.75pt;border-style:solid;border-color:rgb(204,204,204);vertical-align:bottom;background-color:rgb(255,255,255);padding:2pt"><br></td><td style="border-width:0.75pt;border-style:solid;border-color:rgb(204,204,204);vertical-align:bottom;background-color:rgb(255,255,255);padding:2pt"><br></td></tr><tr style="height:15.75pt"><td style="border-width:0.75pt;border-style:solid;border-color:rgb(204,204,204);vertical-align:bottom;background-color:rgb(255,255,255);padding:2pt"><p dir="ltr" style="line-height:1.38;margin-top:0pt;margin-bottom:0pt"><a href="http://rapmusic.com/forums/" style="text-decoration:none" target="_blank" data-saferedirecturl="https://www.google.com/url?q=http://rapmusic.com/forums/&amp;source=gmail&amp;ust=1537498404434000&amp;usg=AFQjCNEbY7ajZIpBFMvNFVix3gisdE5L4A"><span style="font-size:11pt;font-family:Arial;color:rgb(17,85,204);background-color:transparent;font-weight:400;font-style:normal;font-variant:normal;text-decoration:underline;vertical-align:baseline;white-space:pre-wrap">http://rapmusic.com/forums/</span></a></p></td><td style="border-width:0.75pt;border-style:solid;border-color:rgb(204,204,204);vertical-align:bottom;background-color:rgb(255,255,255);padding:2pt"><p dir="ltr" style="line-height:1.38;margin-top:0pt;margin-bottom:0pt"><span style="font-size:11pt;font-family:Arial;color:rgb(0,0,0);background-color:transparent;font-weight:400;font-style:normal;font-variant:normal;text-decoration:none;vertical-align:baseline;white-space:pre-wrap">&amp;93Pjm8&lt;=t7$.zu4VxxxPjm8&lt;=t7$.<wbr>z</span></p></td><td style="border-width:0.75pt;border-style:solid;border-color:rgb(204,204,204);vertical-align:bottom;background-color:rgb(255,255,255);padding:2pt"><p dir="ltr" style="line-height:1.38;margin-top:0pt;margin-bottom:0pt"><span style="font-size:11pt;font-family:Arial;color:rgb(0,0,0);background-color:transparent;font-weight:400;font-style:normal;font-variant:normal;text-decoration:none;vertical-align:baseline;white-space:pre-wrap">This used to be a very busy forum. The person who was tasked with watching it fell asleep on the wheel and the whole forum was overtaken by spammers. Thousands of spam posts in a month. The members could not find their own posts between all the spam and were forced to go elsewhere.</span></p></td></tr><tr style="height:15.75pt"><td style="border-width:0.75pt;border-style:solid;border-color:rgb(204,204,204);vertical-align:bottom;padding:2pt"><br></td><td style="border-width:0.75pt;border-style:solid;border-color:rgb(204,204,204);vertical-align:bottom;padding:2pt"><br></td><td style="border-width:0.75pt;border-style:solid;border-color:rgb(204,204,204);vertical-align:bottom;padding:2pt"><br></td></tr><tr style="height:15.75pt"><td style="border-width:0.75pt;border-style:solid;border-color:rgb(204,204,204);vertical-align:bottom;padding:2pt"><br></td><td style="border-width:0.75pt;border-style:solid;border-color:rgb(204,204,204);vertical-align:bottom;padding:2pt"><br></td><td style="border-width:0.75pt;border-style:solid;border-color:rgb(204,204,204);vertical-align:bottom;padding:2pt"><br></td></tr></tbody></table>
# Out:
# <table style="border:none;border-collapse:collapse"><colgroup><col width="160"><col width="223"><col width="299"></colgroup><tbody><tr style="height:15.75pt"><td style="border-width:0.75pt;border-style:solid;border-color:rgb(204,204,204);vertical-align:bottom;background-color:rgb(255,255,255);padding:2pt"><p dir="ltr" style="line-height:1.38;margin-top:0pt;margin-bottom:0pt"><span style="font-size:11pt;font-family:Arial;color:rgb(0,0,0);background-color:transparent;font-weight:400;font-style:normal;font-variant:normal;text-decoration:none;vertical-align:baseline;white-space:pre-wrap">Site</span></p></td><td style="border-width:0.75pt;border-style:solid;border-color:rgb(204,204,204);vertical-align:bottom;background-color:rgb(255,255,255);padding:2pt"><p dir="ltr" style="line-height:1.38;margin-top:0pt;margin-bottom:0pt"><span style="font-size:11pt;font-family:Arial;color:rgb(0,0,0);background-color:transparent;font-weight:400;font-style:normal;font-variant:normal;text-decoration:none;
# ...

# %%
import pandas as pd
data = [
    ['','writers.net', '', 'vb4.1.3', 0],
    ['','genmay.com', '', 'vb3.8.7', 24550691],
    ['http://wiispace.com/wii-forum/','wiispace.com', '', 'vb3.8.7', 294287],
    ['','digishoptalk.com', '', 'vb3.8.7', 3477125],
    ['https://www.tapatalk.com/groups/writersbeat/index.php','writersbeat.com', '', 'vb3.8.7', 700926],
    ['https://www.tapatalk.com/groups/zuneboards/index.php','zuneboards.com', '', 'vb3.8.7', 610080],
    ['','abxzone.com', '', 'vb3.8.7', 1541420],
    ['http://www.saturnspot.com/','saturnspot.com', '', 'vb3.8.7', 276933],
    #['','parentingforums.com', '', 'vb3.8.7', 125481],
    ['','metalthrone.com', '', 'vb3.8.7', 442519],
    ['http://www.adminfusion.com/','adminfusion.com', 'forums_', 'vb3.8.2', 288115],
    ['http://www.clubconspiracy.com/forum/','clubconspiracy.com', '', 'vb3.6.12', 77605],
    ['http://www.s2000forums.com/forum/','s2000forums.com', '', 'vb3.6.2', 3532],
    ['','darkforum.com', '', 'vb3.8.1', 1382207],
    ['','democracyforums.com', '', 'vb3.8.7', 1552816],
    ['http://www.fishtankforums.com/forum.php','fishtankforums.com', '', 'vb3.8.7', 80833],
    ['http://www.totallyfrugal.com/forums/','totallyfrugal.com', '', 'vb3.8.7', 68325],
]
df = pd.DataFrame(data, columns=["url","forum name", "prefix", "version", "total posts"])
df.sort_values('total posts')
# Out:
#                                                   url           forum name  \
# 0                                                              writers.net
# 11                  http://www.s2000forums.com/forum/      s2000forums.com
# 15               http://www.totallyfrugal.com/forums/    totallyfrugal.com
# 10               http://www.clubconspiracy.com/forum/   clubconspiracy.com
# 14            http://www.fishtankforums.com/forum.php   fishtankforums.com
# 7                          http://www.saturnspot.com/       saturnspot.com
# 9                         http://www.adminfusion.com/      adminfusion.com
# 2                      http://wiispace.com/wii-forum/         wiispace.com
# 8                                                          metalthrone.com
# 5   https://www.tapatalk.com/groups/zuneboards/ind...       zuneboards.com
# 4   https://www.tapatalk.com/groups/writersbeat/in...      writersbeat.com
# ...

# %% [markdown]
# - tapatalk_market_enabled  1
# - tapatalk_market_forums   106
# - tapatalk_market_url   https://beta.panjo.com/
#
# # custom css
#
# for NSFW site, also hide custom option in acp， it's in hs ->modules ->ACP->ACP EXTENTION->HS STYLE. BE very careful about it.
# 在config初始化的地方修改
#
# custom css 选项受config中的 hs_customcss_enabled控制，1显示
#
# 52.45.224.153

# %% [markdown]
# ### premium membership sql
#
# SELECT * FROM quoord_taptaptalk.ttg_payment_history where money <> 0 and target != 'donate' and forum_id not in (25606, 22099, 25058) and username not like 'summer%' and username not like 'ehheh' and username not like 'duanniu' group by forum_id,user_id;

# %% [markdown]
# private function getTapatalkIdToken($ttId)
#    {
#        return “31c6179e77a0f7744504ac507604c9fd”;
#        if (!$ttId || !is_numeric($ttId)) {
#            return false;
#        }
#        $ttidToken = $this->request->variable(‘ttidToken’, ‘’,  \phpbb\request\request_interface::COOKIE);
#        if (!$ttidToken) {
#            $ttidToken = $this->_getTapatalkIdToken($ttId);
#            $this->request->overwrite(‘ttidToken’, $ttidToken, \phpbb\request\request_interface::COOKIE);
#        }
#
#        return $ttidToken;
#    }
#
# private function getTTid()
#    {
#        return “6074637”;
#        $user = $this->user;
#        $ttId = 0;
#        $ttId = (int)$ttId;
#        if (isset($user->data[‘ttid’]) && $user->data[‘ttid’]) {
#            $ttId = $user->data[‘ttid’];
#        }
#        if (!$ttId) {
#            $chatOptions = $this->getChatRoomOptions();
#            if ($chatOptions == 3) $chatOptions = 2;
#            if ($chatOptions !== false && ($chatOptions == CHAT_ROOM_GUEST_CAN_VIEW || $user->data[‘user_id’])) { // chat guest can view
#                $ttId = FAKE_TTID; // set a fake ttid to guest user
#            } else {
#                return false;
#            }
#        }
#        return $ttId;
#    }
# if (!$this->config[‘board_disable’])
#        {
#            global $cache;
#
#            //region Generate user variable;
#            $paramUser = Array();
#            $paramUser[‘user_id’] = “120”;
#            $paramUser[‘username’] = “tangjingyuan”;
#            $paramUser[‘user_avatar’] = “https://groups.tapatalk-cdn.com/avatar/25606/120_1517402180.jpg“;
#            $paramUser[‘tt_username’] = ‘tangjingyuan’;
#            $paramUser[‘ttid’] = ‘6074637’;
#            $paramUser[‘user_status’] = $userStatus;
#            $paramUser[‘fake_ttid’] = FAKE_TTID;
#            //endregion
#
#            $this->template->assign_vars([
#                ‘USER’ => json_encode($paramUser),
#                ‘CHATROOM_INFO’ => json_encode([
#                    ‘forum_id’ => “1974565”,
#                    ‘room_id’ => ‘forum-group-chat-’ . “1974565",
#                    ‘forum_url’ => generate_board_url(),
#                    ‘room_type’ => ‘group’,
#                    ‘chat_option’ => isset($hs_forum_data[‘chat_option’])?$hs_forum_data[‘chat_option’]:1,
#                    ‘mod_list’ => $cache->get(FORUM_CHAT_MOD_LIST)
#                ]),
#                ‘ENABLE_FORUM_CHAT_ONLINE’ => 1
#            ]);
#        }

# %% [markdown]
# <r>&lt;r&gt;&lt;FONT font="Bitstream Charter, serif"&gt;&lt;s&gt;<FONT font="Bitstream Charter, serif"><s>[FONT=Bitstream Charter, serif]</s>&lt;/s&gt;&lt;SIZE size="3"&gt;&lt;s&gt;<SIZE size="125"><s>[size=125]</s>&lt;/s&gt;Dear members,&lt;e&gt;<e>[/SIZE]</e></SIZE>&lt;/e&gt;&lt;/SIZE&gt;&lt;e&gt;<e>[/FONT]</e></FONT>&lt;/e&gt;&lt;/FONT&gt;&lt;br/&gt;<br/>
#  &lt;FONT font="Bitstream Charter, serif"&gt;&lt;s&gt;<FONT font="Bitstream Charter, serif"><s>[FONT=Bitstream Charter, serif]</s>&lt;/s&gt;&lt;SIZE size="3"&gt;&lt;s&gt;<SIZE size="125"><s>[size=125]</s>&lt;/s&gt;&lt;br/&gt;<br/>
# Where our boards used to be a friendly, relaxed, and open-minded  community, lately the tendency to attack one another and not allow for a  diversity of opinions threatens to spoil the experience for both new  and seasoned members who seek a supportive writing environment—one we  would all like the Beat to be.&lt;e&gt;<e>[/SIZE]</e></SIZE>&lt;/e&gt;&lt;/SIZE&gt;&lt;e&gt;<e>[/FONT]</e></FONT>&lt;/e&gt;&lt;/FONT&gt;&lt;br/&gt;<br/>
#  &lt;FONT font="Bitstream Charter, serif"&gt;&lt;s&gt;<FONT font="Bitstream Charter, serif"><s>[FONT=Bitstream Charter, serif]</s>&lt;/s&gt;&lt;SIZE size="3"&gt;&lt;s&gt;<SIZE size="125"><s>[size=125]</s>&lt;/s&gt;&lt;br/&gt;<br/>
# Remember: We are a writer's forum. Writers write and critique each  others' work. We have the Cafe and the Intellectual Table for other  discussions and conversations, but the Write Here forum is our main  focus. As of late, we, the staff, feel we've needed to step in far too  many times to extinguish fires that would not have flared had people  walked away from arguments before they got out of hand.&lt;e&gt;<e>[/SIZE]</e></SIZE>&lt;/e&gt;&lt;/SIZE&gt;&lt;e&gt;<e>[/FONT]</e></FONT>&lt;/e&gt;&lt;/FONT&gt;&lt;br/&gt;<br/>
#  &lt;FONT font="Bitstream Charter, serif"&gt;&lt;s&gt;<FONT font="Bitstream Charter, serif"><s>[FONT=Bitstream Charter, serif]</s>&lt;/s&gt;&lt;SIZE size="3"&gt;&lt;s&gt;<SIZE size="125"><s>[size=125]</s>&lt;/s&gt;&lt;br/&gt;<br/>
# Most of us seek to improve our writing. Please give critiques in a way you, yourself, would like to receive them, and critique &lt;e&gt;<e>[/SIZE]</e></SIZE>&lt;/e&gt;&lt;/SIZE&gt;&lt;e&gt;<e>[/FONT]</e></FONT>&lt;/e&gt;&lt;/FONT&gt;&lt;FONT font="Bitstream Charter, serif"&gt;&lt;s&gt;<FONT font="Bitstream Charter, serif"><s>[FONT=Bitstream Charter, serif]</s>&lt;/s&gt;&lt;SIZE size="3"&gt;&lt;s&gt;<SIZE size="125"><s>[size=125]</s>&lt;/s&gt;&lt;U&gt;&lt;s&gt;<U><s>[U]</s>&lt;/s&gt;the piece&lt;e&gt;<e>[/U]</e></U>&lt;/e&gt;&lt;/U&gt;&lt;e&gt;<e>[/SIZE]</e></SIZE>&lt;/e&gt;&lt;/SIZE&gt;&lt;e&gt;<e>[/FONT]</e></FONT>&lt;/e&gt;&lt;/FONT&gt;&lt;FONT font="Bitstream Charter, serif"&gt;&lt;s&gt;<FONT font="Bitstream Charter, serif"><s>[FONT=Bitstream Charter, serif]</s>&lt;/s&gt;&lt;SIZE size="3"&gt;&lt;s&gt;<SIZE size="125"><s>[size=125]</s>&lt;/s&gt;,  not belittle the writer nor other critiques given before yours. If your  work has been critiqued, please remember the critic has taken the time  and effort to mark up your piece. Be graceful, even if you don't like  what's been said about your work. (See our &lt;URL url="<URL url="http://forums.writersbeat.com/faq.php?faq=writers_beat#faq_critiquing%22%3E%3Cs"><LINK_TEXT text="http://forums.writersbeat.com/faq.php?f ... iquing&quot;&gt;&lt;s">http://forums.writersbeat.com/faq.php?faq=writers_beat#faq_critiquing"&gt;&lt;s</LINK_TEXT></URL>&gt;<URL url="http://forums.writersbeat.com/faq.php?faq=writers_beat#faq_critiquing"><s>[URL="http://forums.writersbeat.com/faq.php?faq=writers_beat#faq_critiquing"]</s>&lt;/s&gt;FAQ&lt;e&gt;<e>[/URL]</e></URL>&lt;/e&gt;&lt;/URL&gt;) Better to receive  constructive criticism in a supportive environment where a project could  be improved, than to publish and later discover your project needed  more work.&lt;e&gt;<e>[/SIZE]</e></SIZE>&lt;/e&gt;&lt;/SIZE&gt;&lt;e&gt;<e>[/FONT]</e></FONT>&lt;/e&gt;&lt;/FONT&gt;&lt;br/&gt;<br/>
#  &lt;FONT font="Bitstream Charter, serif"&gt;&lt;s&gt;<FONT font="Bitstream Charter, serif"><s>[FONT=Bitstream Charter, serif]</s>&lt;/s&gt;&lt;SIZE size="3"&gt;&lt;s&gt;<SIZE size="125"><s>[size=125]</s>&lt;/s&gt;&lt;br/&gt;<br/>
# Please note: The majority of our members are adults. It's expected adults will act accordingly—&lt;e&gt;<e>[/SIZE]</e></SIZE>&lt;/e&gt;&lt;/SIZE&gt;&lt;e&gt;<e>[/FONT]</e></FONT>&lt;/e&gt;&lt;/FONT&gt;&lt;FONT font="Bitstream Charter, serif"&gt;&lt;s&gt;<FONT font="Bitstream Charter, serif"><s>[FONT=Bitstream Charter, serif]</s>&lt;/s&gt;&lt;SIZE size="3"&gt;&lt;s&gt;<SIZE size="125"><s>[size=125]</s>&lt;/s&gt;&lt;U&gt;&lt;s&gt;<U><s>[U]</s>&lt;/s&gt;with good sense and maturity&lt;e&gt;<e>[/U]</e></U>&lt;/e&gt;&lt;/U&gt;&lt;e&gt;<e>[/SIZE]</e></SIZE>&lt;/e&gt;&lt;/SIZE&gt;&lt;e&gt;<e>[/FONT]</e></FONT>&lt;/e&gt;&lt;/FONT&gt;&lt;FONT font="Bitstream Charter, serif"&gt;&lt;s&gt;<FONT font="Bitstream Charter, serif"><s>[FONT=Bitstream Charter, serif]</s>&lt;/s&gt;&lt;SIZE size="3"&gt;&lt;s&gt;<SIZE size="125"><s>[size=125]</s>&lt;/s&gt;.&lt;e&gt;<e>[/SIZE]</e></SIZE>&lt;/e&gt;&lt;/SIZE&gt;&lt;e&gt;<e>[/FONT]</e></FONT>&lt;/e&gt;&lt;/FONT&gt;&lt;br/&gt;<br/>
#  &lt;FONT font="Bitstream Charter, serif"&gt;&lt;s&gt;<FONT font="Bitstream Charter, serif"><s>[FONT=Bitstream Charter, serif]</s>&lt;/s&gt;&lt;SIZE size="3"&gt;&lt;s&gt;<SIZE size="125"><s>[size=125]</s>&lt;/s&gt;&lt;br/&gt;<br/>
# So, let's end this year and start the next more cordially around the  Beat, and not spiral down into a community where no critique is well  received and members haven't the common courtesy to grant each other  their diverse and varied opinions. (And yes, this extends to &lt;e&gt;<e>[/SIZE]</e></SIZE>&lt;/e&gt;&lt;/SIZE&gt;&lt;e&gt;<e>[/FONT]</e></FONT>&lt;/e&gt;&lt;/FONT&gt;&lt;FONT font="Bitstream Charter, serif"&gt;&lt;s&gt;<FONT font="Bitstream Charter, serif"><s>[FONT=Bitstream Charter, serif]</s>&lt;/s&gt;&lt;SIZE size="3"&gt;&lt;s&gt;<SIZE size="125"><s>[size=125]</s>&lt;/s&gt;&lt;U&gt;&lt;s&gt;<U><s>[U]</s>&lt;/s&gt;all&lt;e&gt;<e>[/U]</e></U>&lt;/e&gt;&lt;/U&gt;&lt;e&gt;<e>[/SIZE]</e></SIZE>&lt;/e&gt;&lt;/SIZE&gt;&lt;e&gt;<e>[/FONT]</e></FONT>&lt;/e&gt;&lt;/FONT&gt;&lt;FONT font="Bitstream Charter, serif"&gt;&lt;s&gt;<FONT font="Bitstream Charter, serif"><s>[FONT=Bitstream Charter, serif]</s>&lt;/s&gt;&lt;SIZE size="3"&gt;&lt;s&gt;<SIZE size="125"><s>[size=125]</s>&lt;/s&gt; areas of our forum, Intellectual Table included—please review the &lt;URL url="<URL url="http://www.writersbeat.com/showthread.php?t=16632%22%3E%3Cs">http://www.writersbeat.com/showthread.php?t=16632"&gt;&lt;s</URL>&gt;<URL url="http://www.writersbeat.com/showthread.php?t=16632"><s>[URL="http://www.writersbeat.com/showthread.php?t=16632"]</s>&lt;/s&gt;IT rules and guidelines&lt;e&gt;<e>[/URL]</e></URL>&lt;/e&gt;&lt;/URL&gt;.)&lt;e&gt;<e>[/SIZE]</e></SIZE>&lt;/e&gt;&lt;/SIZE&gt;&lt;e&gt;<e>[/FONT]</e></FONT>&lt;/e&gt;&lt;/FONT&gt;&lt;br/&gt;<br/>
#  &lt;FONT font="Bitstream Charter, serif"&gt;&lt;s&gt;<FONT font="Bitstream Charter, serif"><s>[FONT=Bitstream Charter, serif]</s>&lt;/s&gt;&lt;SIZE size="3"&gt;&lt;s&gt;<SIZE size="125"><s>[size=125]</s>&lt;/s&gt;&lt;br/&gt;<br/>
# Thank you all for your cooperation,&lt;e&gt;<e>[/SIZE]</e></SIZE>&lt;/e&gt;&lt;/SIZE&gt;&lt;e&gt;<e>[/FONT]</e></FONT>&lt;/e&gt;&lt;/FONT&gt;&lt;br/&gt;<br/>
#  &lt;FONT font="Bitstream Charter, serif"&gt;&lt;s&gt;<FONT font="Bitstream Charter, serif"><s>[FONT=Bitstream Charter, serif]</s>&lt;/s&gt;&lt;SIZE size="3"&gt;&lt;s&gt;<SIZE size="125"><s>[size=125]</s>&lt;/s&gt;&lt;br/&gt;<br/>
# Writer's Beat Staff&lt;e&gt;<e>[/SIZE]</e></SIZE>&lt;/e&gt;&lt;/SIZE&gt;&lt;e&gt;<e>[/FONT]</e></FONT>&lt;/e&gt;&lt;/FONT&gt;&lt;/r&gt;</r>

# %% [markdown]
# # group_id, forum_id, auth_option_id, auth_role_id, auth_setting
# '34', '0', '91', '0', '-1'
# '34', '0', '99', '0', '-1'
# '34', '0', '117', '0', '-1'
# '34', '0', '32', '0', '-1'
# '34', '0', '9', '0', '-1'
# '34', '0', '18', '0', '-1'
# '34', '0', '4', '0', '-1'
# '34', '0', '8', '0', '-1'
# '34', '0', '15', '0', '-1'
# '34', '0', '21', '0', '-1'
# '34', '0', '28', '0', '-1'
# '34', '0', '17', '0', '-1'
# '34', '0', '30', '0', '-1'
# '34', '0', '16', '0', '-1'
# '3', '0', '91', '0', '-1'
# '3', '0', '99', '0', '-1'
# '3', '0', '121', '0', '-1'
# '3', '0', '32', '0', '-1'
# '3', '0', '9', '0', '-1'
# '3', '0', '18', '0', '-1'
# '3', '0', '4', '0', '-1'
# '3', '0', '25', '0', '-1'
# '3', '0', '8', '0', '-1'
# '3', '0', '17', '0', '-1'
# '3', '0', '30', '0', '-1'
# '22', '0', '32', '0', '-1'
# '22', '0', '9', '0', '-1'
# '22', '0', '18', '0', '-1'
# '22', '0', '16', '0', '-1'
# '35', '0', '99', '0', '-1'
# '35', '0', '117', '0', '-1'
# '35', '0', '32', '0', '-1'
# '35', '0', '9', '0', '-1'
# '35', '0', '18', '0', '-1'
# '35', '0', '8', '0', '-1'
# '35', '0', '15', '0', '-1'
# '35', '0', '21', '0', '-1'
# '35', '0', '28', '0', '-1'
# '35', '0', '16', '0', '-1'
# '10', '0', '32', '0', '-1'
# '10', '0', '9', '0', '-1'
# '10', '0', '16', '0', '-1'
# '23', '0', '32', '0', '-1'
# '23', '0', '9', '0', '-1'
# '23', '0', '18', '0', '-1'
# '23', '0', '16', '0', '-1'
# '25', '0', '32', '0', '-1'
# '25', '0', '16', '0', '-1'
# '27', '0', '91', '0', '-1'
# '27', '0', '99', '0', '-1'
# '27', '0', '32', '0', '-1'
# '27', '0', '9', '0', '-1'
# '27', '0', '4', '0', '-1'
# '27', '0', '8', '0', '-1'
# '27', '0', '16', '0', '-1'
# '11', '0', '32', '0', '-1'
# '11', '0', '9', '0', '-1'
# '11', '0', '18', '0', '-1'
# '11', '0', '16', '0', '-1'
# '2', '0', '91', '0', '-1'
# '2', '0', '117', '0', '-1'
# '2', '0', '32', '0', '-1'
# '2', '0', '18', '0', '-1'
# '2', '0', '4', '0', '-1'
# '32', '0', '91', '0', '-1'
# '32', '0', '32', '0', '-1'
# '32', '0', '4', '0', '-1'
# '1', '0', '91', '0', '-1'
# '1', '0', '99', '0', '-1'
# '1', '0', '121', '0', '-1'
# '1', '0', '32', '0', '-1'
# '1', '0', '9', '0', '-1'
# '1', '0', '18', '0', '-1'
# '1', '0', '4', '0', '-1'
# '1', '0', '25', '0', '-1'
# '1', '0', '8', '0', '-1'
# '1', '0', '17', '0', '-1'
# '1', '0', '30', '0', '-1'
# '7', '0', '91', '0', '-1'
# '7', '0', '99', '0', '-1'
# '7', '0', '121', '0', '-1'
# '7', '0', '32', '0', '-1'
# '7', '0', '9', '0', '-1'
# '7', '0', '18', '0', '-1'
# '7', '0', '4', '0', '-1'
# '7', '0', '25', '0', '-1'
# '7', '0', '8', '0', '-1'
# '7', '0', '17', '0', '-1'
# '7', '0', '30', '0', '-1'
# '14', '0', '32', '0', '-1'
# '14', '0', '9', '0', '-1'
# '14', '0', '18', '0', '-1'
# '14', '0', '16', '0', '-1'
# '33', '0', '91', '0', '-1'
# '33', '0', '32', '0', '-1'
# '33', '0', '4', '0', '-1'

# %% [markdown]
# # group_id, forum_id, auth_option_id, auth_role_id, auth_setting
# '5', '0', '0', '5', '0'
# '5', '0', '0', '1', '0'
# '2', '0', '0', '6', '0'
# '3', '0', '0', '6', '0'
# '4', '0', '0', '5', '0'
# '4', '0', '0', '10', '0'
# '7', '0', '0', '23', '0'
# '3', '0', '91', '0', '-1'
# '3', '0', '99', '0', '-1'
# '3', '0', '121', '0', '-1'
# '3', '0', '117', '0', '1'
# '3', '0', '32', '0', '-1'
# b
# '3', '0', '8', '0', '-1'
# '3', '0', '15', '0', '1'
# '3', '0', '21', '0', '1'
# '3', '0', '28', '0', '1'
# '3', '0', '17', '0', '-1'
# '3', '0', '30', '0', '-1'
# '3', '0', '16', '0', '1'
# '5', '0', '91', '0', '1'
# '5', '0', '99', '0', '1'
# '5', '0', '121', '0', '1'
# '5', '0', '117', '0', '1'
# '5', '0', '32', '0', '1'
# '5', '0', '9', '0', '1'
# '5', '0', '18', '0', '1'
# '5', '0', '4', '0', '1'
# '5', '0', '25', '0', '1'
# '5', '0', '8', '0', '1'
# '5', '0', '15', '0', '1'
# '5', '0', '21', '0', '1'
# '5', '0', '28', '0', '1'
# '5', '0', '17', '0', '1'
# '5', '0', '30', '0', '1'
# '5', '0', '16', '0', '1'
# '9', '0', '91', '0', '1'
# '9', '0', '99', '0', '1'
# '9', '0', '121', '0', '1'
# '9', '0', '117', '0', '1'
# '9', '0', '32', '0', '-1'
# '9', '0', '9', '0', '-1'
# '9', '0', '18', '0', '-1'
# '9', '0', '4', '0', '1'
# '9', '0', '25', '0', '1'
# '9', '0', '8', '0', '1'
# '9', '0', '15', '0', '1'
# '9', '0', '21', '0', '1'
# '9', '0', '28', '0', '1'
# '9', '0', '17', '0', '1'
# '9', '0', '30', '0', '1'
# '9', '0', '16', '0', '-1'
# '10', '0', '91', '0', '1'
# '10', '0', '99', '0', '1'
# '10', '0', '121', '0', '1'
# '10', '0', '117', '0', '1'
# '10', '0', '32', '0', '-1'
# '10', '0', '9', '0', '-1'
# '10', '0', '18', '0', '-1'
# '10', '0', '4', '0', '1'
# '10', '0', '25', '0', '1'
# '10', '0', '8', '0', '1'
# '10', '0', '15', '0', '1'
# '10', '0', '21', '0', '1'
# '10', '0', '28', '0', '1'
# '10', '0', '17', '0', '1'
# '10', '0', '30', '0', '1'
# '10', '0', '16', '0', '-1'
# '2', '0', '91', '0', '1'
# '2', '0', '99', '0', '1'
# '2', '0', '121', '0', '1'
# '2', '0', '117', '0', '1'
# '2', '0', '32', '0', '1'
# '2', '0', '9', '0', '1'
# '2', '0', '18', '0', '1'
# '2', '0', '4', '0', '1'
# '2', '0', '25', '0', '1'
# '2', '0', '8', '0', '1'
# '2', '0', '15', '0', '1'
# '2', '0', '21', '0', '1'
# '2', '0', '28', '0', '1'
# '2', '0', '17', '0', '1'
# '2', '0', '30', '0', '1'
# '2', '0', '16', '0', '1'
# '4', '0', '91', '0', '1'
# '4', '0', '99', '0', '1'
# '4', '0', '121', '0', '1'
# '4', '0', '117', '0', '1'
# '4', '0', '32', '0', '1'
# '4', '0', '9', '0', '1'
# '4', '0', '18', '0', '1'
# '4', '0', '4', '0', '1'
# '4', '0', '25', '0', '1'
# '4', '0', '8', '0', '1'
# '4', '0', '15', '0', '1'
# '4', '0', '21', '0', '1'
# '4', '0', '28', '0', '1'
# '4', '0', '17', '0', '1'
# '4', '0', '30', '0', '1'
# '4', '0', '16', '0', '1'
# '1', '0', '91', '0', '-1'
# '1', '0', '99', '0', '-1'
# '1', '0', '121', '0', '-1'
# '1', '0', '117', '0', '1'
# '1', '0', '32', '0', '-1'
# '1', '0', '9', '0', '-1'
# '1', '0', '18', '0', '-1'
# '1', '0', '4', '0', '-1'
# '1', '0', '25', '0', '-1'
# '1', '0', '8', '0', '-1'
# '1', '0', '15', '0', '1'
# '1', '0', '21', '0', '1'
# '1', '0', '28', '0', '1'
# '1', '0', '17', '0', '-1'
# '1', '0', '30', '0', '-1'
# '1', '0', '16', '0', '1'
# '7', '0', '91', '0', '-1'
# '7', '0', '99', '0', '-1'
# '7', '0', '121', '0', '-1'
# '7', '0', '117', '0', '1'
# '7', '0', '32', '0', '-1'
# '7', '0', '9', '0', '-1'
# '7', '0', '18', '0', '-1'
# '7', '0', '4', '0', '-1'
# '7', '0', '25', '0', '-1'
# '7', '0', '8', '0', '-1'
# '7', '0', '15', '0', '1'
# '7', '0', '21', '0', '1'
# '7', '0', '28', '0', '1'
# '7', '0', '17', '0', '-1'
# '7', '0', '30', '0', '-1'
# '7', '0', '16', '0', '1'

# %% [markdown]
# # user_id, forum_id, auth_option_id, auth_role_id, auth_setting
# '1', '0', '34', '0', '1'
# '1', '0', '36', '0', '1'
# '1', '0', '37', '0', '1'
# '2', '2', '34', '0', '1'
# '2', '2', '36', '0', '-1'
# '2', '2', '37', '0', '1'

# %% [markdown]
# define("PAYPAL_PLAN1","P-7MY87496R26556454WVYSQEQ");
# define("PAYPAL_PLAN2","P-0NH77445CE2667204WVYTUAA");
# define("PAYPAL_PLAN3","P-0TP270576N221603MWVYUWLA");
# define("PAYPAL_PLAN4","P-5XL464244Y935472HWVYVVOQ");
#
# P-7MY87496R26556454WVYSQEQ
# P-0NH77445CE2667204WVYTUAA
# P-0TP270576N221603MWVYUWLA
# P-5XL464244Y935472HWVYVVOQ
#
# Array ( [0] => PayPal\Api\Plan Object ( [_propMap:PayPal\Common\PayPalModel:private] => Array ( [id] => P-7MY87496R26556454WVYSQEQ [state] => ACTIVE [name] => $5 per month [description] => Subscription $5.00 per month [type] => INFINITE [payment_definitions] => Array ( [0] => PayPal\Api\PaymentDefinition Object ( [_propMap:PayPal\Common\PayPalModel:private] => Array ( [id] => PD-7M2255280J322510VWVYSQEQ [name] => Regular Payments [type] => REGULAR [frequency] => Month [amount] => PayPal\Api\Currency Object ( [_propMap:PayPal\Common\PayPalModel:private] => Array ( [currency] => USD [value] => 5 ) ) [cycles] => 0 [frequency_interval] => 1 ) ) ) [merchant_preferences] => PayPal\Api\MerchantPreferences Object ( [_propMap:PayPal\Common\PayPalModel:private] => Array ( [setup_fee] => PayPal\Api\Currency Object ( [_propMap:PayPal\Common\PayPalModel:private] => Array ( [currency] => USD [value] => 5 ) ) [max_fail_attempts] => 1 [return_url] => https://www.tapatalk.com/paypal/plan/web_return [cancel_url] => https://www.tapatalk.com/paypal/plan/web_cancel [auto_bill_amount] => YES [initial_fail_amount_action] => CANCEL ) ) [create_time] => 2019-05-14T08:24:13.074Z [update_time] => 2019-05-14T08:24:14.603Z [links] => Array ( [0] => PayPal\Api\Links Object ( [_propMap:PayPal\Common\PayPalModel:private] => Array ( [href] => https://api.paypal.com/v1/payments/billing-plans/P-7MY87496R26556454WVYSQEQ [rel] => self [method] => GET ) ) ) ) ) [1] => PayPal\Api\Plan Object ( [_propMap:PayPal\Common\PayPalModel:private] => Array ( [id] => P-0NH77445CE2667204WVYTUAA [state] => ACTIVE [name] => $10 per month [description] => Subscription $10.00 per month [type] => INFINITE [payment_definitions] => Array ( [0] => PayPal\Api\PaymentDefinition Object ( [_propMap:PayPal\Common\PayPalModel:private] => Array ( [id] => PD-78315914EV974684TWVYTUAA [name] => Regular Payments [type] => REGULAR [frequency] => Month [amount] => PayPal\Api\Currency Object ( [_propMap:PayPal\Common\PayPalModel:private] => Array ( [currency] => USD [value] => 10 ) ) [cycles] => 0 [frequency_interval] => 1 ) ) ) [merchant_preferences] => PayPal\Api\MerchantPreferences Object ( [_propMap:PayPal\Common\PayPalModel:private] => Array ( [setup_fee] => PayPal\Api\Currency Object ( [_propMap:PayPal\Common\PayPalModel:private] => Array ( [currency] => USD [value] => 10 ) ) [max_fail_attempts] => 1 [return_url] => https://www.tapatalk.com/paypal/plan/web_return [cancel_url] => https://www.tapatalk.com/paypal/plan/web_cancel [auto_bill_amount] => YES [initial_fail_amount_action] => CANCEL ) ) [create_time] => 2019-05-14T08:24:17.664Z [update_time] => 2019-05-14T08:24:19.191Z [links] => Array ( [0] => PayPal\Api\Links Object ( [_propMap:PayPal\Common\PayPalModel:private] => Array ( [href] => https://api.paypal.com/v1/payments/billing-plans/P-0NH77445CE2667204WVYTUAA [rel] => self [method] => GET ) ) ) ) ) [2] => PayPal\Api\Plan Object ( [_propMap:PayPal\Common\PayPalModel:private] => Array ( [id] => P-0TP270576N221603MWVYUWLA [state] => ACTIVE [name] => $20 per month [description] => Subscription $20.00 per month [type] => INFINITE [payment_definitions] => Array ( [0] => PayPal\Api\PaymentDefinition Object ( [_propMap:PayPal\Common\PayPalModel:private] => Array ( [id] => PD-9Y262693NY4581438WVYUWLA [name] => Regular Payments [type] => REGULAR [frequency] => Month [amount] => PayPal\Api\Currency Object ( [_propMap:PayPal\Common\PayPalModel:private] => Array ( [currency] => USD [value] => 20 ) ) [cycles] => 0 [frequency_interval] => 1 ) ) ) [merchant_preferences] => PayPal\Api\MerchantPreferences Object ( [_propMap:PayPal\Common\PayPalModel:private] => Array ( [setup_fee] => PayPal\Api\Currency Object ( [_propMap:PayPal\Common\PayPalModel:private] => Array ( [currency] => USD [value] => 20 ) ) [max_fail_attempts] => 1 [return_url] => https://www.tapatalk.com/paypal/plan/web_return [cancel_url] => https://www.tapatalk.com/paypal/plan/web_cancel [auto_bill_amount] => YES [initial_fail_amount_action] => CANCEL ) ) [create_time] => 2019-05-14T08:24:22.060Z [update_time] => 2019-05-14T08:24:23.396Z [links] => Array ( [0] => PayPal\Api\Links Object ( [_propMap:PayPal\Common\PayPalModel:private] => Array ( [href] => https://api.paypal.com/v1/payments/billing-plans/P-0TP270576N221603MWVYUWLA [rel] => self [method] => GET ) ) ) ) ) [3] => PayPal\Api\Plan Object ( [_propMap:PayPal\Common\PayPalModel:private] => Array ( [id] => P-5XL464244Y935472HWVYVVOQ [state] => ACTIVE [name] => $50 per month [description] => Subscription $50.00 per month [type] => INFINITE [payment_definitions] => Array ( [0] => PayPal\Api\PaymentDefinition Object ( [_propMap:PayPal\Common\PayPalModel:private] => Array ( [id] => PD-9PY94654YK353323CWVYVVOQ [name] => Regular Payments [type] => REGULAR [frequency] => Month [amount] => PayPal\Api\Currency Object ( [_propMap:PayPal\Common\PayPalModel:private] => Array ( [currency] => USD [value] => 50 ) ) [cycles] => 0 [frequency_interval] => 1 ) ) ) [merchant_preferences] => PayPal\Api\MerchantPreferences Object ( [_propMap:PayPal\Common\PayPalModel:private] => Array ( [setup_fee] => PayPal\Api\Currency Object ( [_propMap:PayPal\Common\PayPalModel:private] => Array ( [currency] => USD [value] => 50 ) ) [max_fail_attempts] => 1 [return_url] => https://www.tapatalk.com/paypal/plan/web_return [cancel_url] => https://www.tapatalk.com/paypal/plan/web_cancel [auto_bill_amount] => YES [initial_fail_amount_action] => CANCEL ) ) [create_time] => 2019-05-14T08:24:26.042Z [update_time] => 2019-05-14T08:24:27.355Z [links] => Array ( [0] => PayPal\Api\Links Object ( [_propMap:PayPal\Common\PayPalModel:private] => Array ( [href] => https://api.paypal.com/v1/payments/billing-plans/P-5XL464244Y935472HWVYVVOQ [rel] => self [method] => GET ) ) ) ) ) )
