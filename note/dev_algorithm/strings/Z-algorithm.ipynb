# %% [markdown]
# Z algorithm is a linear time string matching algorithm which runs in complexity $O(n)$. It is used to find all occurrence of a pattern $P$ in a string , which is common string searching problem.
#
# __Algorithm__
#
# Given a string $S$ of length $n$, the Z Algorithm produces an array $Z$ where __$Z[i]$ is the length of the longest substring starting from $S[i]$ which is also a prefix of $S$__,
# i.e. the maximum $k$ such that $S[j]=S[i+j]$ for all $0 \leq j < k$. Note that $Z[0] = 0$ means that $S[0] \neq S[i]$. For easier terminology, let's refer to substrings which are also a prefix as prefix-substrings.
#
#
# The algorithm relies on a single, crucial invariant. __Iterate over the letters in the string (index i from 1 to n-1)__ and maintain an interval $[L, R]$ which is the interval with __maximum $R$ such that $1 \leq L \leq i \leq R $ and $S[L\dots R]$ is a prefix-substring__ (if no such interval exists, just let $L=R=-1$).
#
#
# For $i=1$, simply compute $L$ and $R$ by comparing $S[0\dots]$ to $S[1\dots]$. $Z[1]$ is obtained during this process.
#
#
# Now, suppose the correct interval $[L, R]$ for $i-1$ and all of the $Z$ values up to $i-1$. Compute $Z[i]$ and the new $[L,R]$ by the following steps:
#
# - If $i > R$, then there does not exist a prefix-substring of $S$ that starts before $i$ and ends at or after $i$. If such a substring existed, $[L, R]$ would have been the interval for that substring rather than its current value. Thus "reset" and compute a new $[L, R]$ by comparing $S[0\dots]$ to $S[i\dots]$ and get $Z[i]$ at the same time $(Z[i] = R- L + 1)$.
#
# - Otherwise, $i \leq R$, so the current $[L, R]$ extends at least to $i$. Let $k= i- L$. It is known that $Z[i]\geq min(Z[k], R - i + 1)$ because $S[i\dots]$ matches $S[k\dots]$ for at least $R-i + 1$ characters (they are in the $[L, R]$ interval which is known to be prefix-substring).
#
# - If $Z[k] < R -i+1$, then there is no longer prefix-substring starting ar $S[i]$ (or else $Z[k]$ would be larger), meaning $Z[i]=Z[k]$ and $[L, R]$ stays the same. The latter is true becasue $[L, R]$ only changes if there is a prefix-substring starting at $S[i]$ that extends beyond $R$, which is not the case here.
#
# - If $Z[k] \ge R-i+1$, then it is possible for $S[i\dots]$ to match $S[0\dots]$ for more than $R-i+1$ characters(i.e past postion $R$). Thus, there's a need to update $[L, R]$ by setting $L =i$ and matching from $S[R+1]$ forward to obtain the new $R$. Again, $Z[i]$ is obtained during this process.

# %%
# Note that the optimization L = R = i is used when S[0] \neq S[i]
# (it doesn't affect the algorithm since at the next iteration  regardless).
"""
int L = 0, R = 0;
for (int i = 1; i < n; i++) 
{
    if (i > R) 
    {
        L = R = i;
        while (R < n && s[R-L] == s[R]) 
        {
            R++;
        }
        z[i] = R-L; 
        R--;
    } 
    else 
    {
        int k = i-L;
        if (z[k] < R-i+1) 
        {
            z[i] = z[k];
        } 
        else 
        {
            L = i;
            while (R < n && s[R-L] == s[R]) 
            {
                R++;
            }
            z[i] = R-L; 
            R--;
        }
    }
}
"""

def z_algo(text):
    n = len(text)
    z_arr = [0 for i in range(n)]
    l, r = 0, 0
    
    for i in range(1, n):
        if i > r:
            l = r = i
            while r < n and text[r-l] == text[r]:
                r += 1
            z_arr[i] = r-l
            r-=1
        else:
            k=i-l
            if z_arr[k] < r-l+1:
                z_arr[i] = z_arr[k]
            else:
                l=i
                while r < n and text[r-l] == text[r]:
                    r+=1
                z_arr[i] = r-l
                r-=1
    print(z_arr)
    return z_arr

text = 'abracadabra'
# check that your code works correctly on provided example
assert z_algo(text) == [0, 0, 0, 1, 0, 1, 0, 4, 0, 0, 1], 'Wrong answer'
# Out:
# [0, 0, 0, 1, 0, 1, 0, 4, 0, 0, 1]

# %%
def zFunction(text):
    n = len(text)
    z_func = [0 for i in range(n)]

    # YOUR CODE GOES HERE
    l, r= 0, 0

    for i in range(1, n):
        if i <= r:
            z_func[i] = min(z_func[i-1], r-i+1)

        while i + z_func[i] < n and text[z_func[i] +i] == text[z_func[i]]:
            z_func[i] += 1


        new_r = i + z_func[i] - 1
        if new_r > r:
            l, r = i, new_r
    print(z_func)
    return z_func

text = 'abracadabra'
# check that your code works correctly on provided example
assert zFunction(text) == [0, 0, 0, 1, 0, 1, 0, 4, 0, 0, 1], 'Wrong answer'
# Out:
# [0, 0, 0, 1, 0, 1, 0, 4, 3, 2, 1]
# AssertionErrorTraceback (most recent call last)
# <ipython-input-3-584fd453b283> in <module>()
#      22 text = 'abracadabra'
#      23 # check that your code works correctly on provided example
# ---> 24 assert zFunction(text) == [0, 0, 0, 1, 0, 1, 0, 4, 0, 0, 1], 'Wrong answer'
#
# AssertionError: Wrong answer

# %%
show_debug = False

def shortestCycle(cyclic_string):
    shortest_cycle = float("inf")

    # YOUR CODE GOES HERE
    s_l = len(cyclic_string)
    """
    # initializing the array aux with 0's
    aux = [0] * s_l

    # print(concat)

    # for index 0, it will always be 0
    # so starting from index 1
    i = 1
    # m can also be viewed as index of first mismatch
    m = 0
    while i < s_l:
        # prefix = suffix till m-1
        if cyclic_string[i] == cyclic_string[m]:
            m += 1
            aux[i] = m
            i += 1
        # this one is a little tricky,
        # when there is a mismatch,
        # we will check the index of previous
        # possible prefix.
        elif cyclic_string[i] != cyclic_string[m] and m != 0:
            # Note that we do not increment i here.
            m = aux[m-1]
        else:
            # m = 0, we move to the next letter,
            # there was no any prefix found which 
            # is equal to the suffix for index i
            aux[i] = 0
            i += 1

    print(aux)
    """

    z = [0 for i in range(s_l)]

    l, r, k = 0, 0, 0
    for i in range(1, s_l): 
  
        # if i>R nothing matches so we will calculate. 
        # Z[i] using naive way. 
        if i > r: 
            l, r = i, i 
  
            # R-L = 0 in starting, so it will start 
            # checking from 0'th index. For example, 
            # for "ababab" and i = 1, the value of R 
            # remains 0 and Z[i] becomes 0. For string 
            # "aaaaaa" and i = 1, Z[i] and R become 5 
            while r < s_l and cyclic_string[r - l] == cyclic_string[r]: 
                r += 1
            z[i] = r - l 
            r -= 1
        else: 
  
            # k = i-L so k corresponds to number which 
            # matches in [L,R] interval. 
            k = i - l 
  
            # if Z[k] is less than remaining interval 
            # then Z[i] will be equal to Z[k]. 
            # For example, str = "ababab", i = 3, R = 5 
            # and L = 2 
            if z[k] < r - i + 1: 
                z[i] = z[k] 
  
            # For example str = "aaaaaa" and i = 2,  
            # R is 5, L is 0 
            else: 
  
                # else start from R and check manually 
                l = i 
                while r < s_l and cyclic_string[r - l] == cyclic_string[r]: 
                    r += 1
                z[i] = r - l 
                r -= 1
        
    repeated_times = len([x for x in z if x != 0]) + 1
    shortest_cycle = s_l // repeated_times

    if show_debug:
        print(repeated_times, z)

    return shortest_cycle

import string
import random

cyclic_string = 'ababab'
# check that your code works correctly on provided example
# assert shortestCycle(cyclic_string) == 3, 'Wrong answer'

def get_random_string(length):
    letters = string.ascii_lowercase
    # return ''.join(random.sample(letters, length))
    return ''.join(random.choice(letters) for i in range(length))

def cyclisc_string(s, max_repeat = 4, min_repeat = 1):
    repest_times = random.randrange(min_repeat, max_repeat)

    return s * repest_times, repest_times

test_case = 10000
max_string_len = 5
max_repeat = 10
min_repeat = 1

for n in range(test_case):
    length = random.randrange(1, max_string_len)

    random_string = get_random_string(length)
    repeated_string, repeated_times = cyclisc_string(random_string, max_repeat, min_repeat)

    result = shortestCycle(repeated_string)

    if len(random_string) != result:
        show_debug = True
        shortestCycle(repeated_string)
        print("failed!! origin_string '{}', repeated_string '{}', repeated_times '{}', wrong result '{}'"
            .format(random_string, repeated_string, repeated_times, result))

        print('tested %d cases' % n)
        break
# Out:
# Pattern found at index 1
# Pattern found at index 8
# [3, 10, 19]

# %% [markdown]
# __example__
#
# String S has been written over and over and over, and you are presented with a result: "SSSSSSS...". Find the length of the shortest possible S.

# %%
show_debug = False

def shortestCycle(cyclic_string):
    shortest_cycle = float("inf")

    # YOUR CODE GOES HERE
    s_l = len(cyclic_string)

    z = [0 for i in range(s_l)]

    max_i = (0,0)

    l, r, k = 0, 0, 0
    for i in range(1, s_l): 
  
        # if i>R nothing matches so we will calculate. 
        # Z[i] using naive way. 
        if i > r: 
            l, r = i, i 
  
            # R-L = 0 in starting, so it will start 
            # checking from 0'th index. For example, 
            # for "ababab" and i = 1, the value of R 
            # remains 0 and Z[i] becomes 0. For string 
            # "aaaaaa" and i = 1, Z[i] and R become 5 
            while r < s_l and cyclic_string[r - l] == cyclic_string[r]: 
                r += 1
            z[i] = r - l 
            r -= 1
        else: 
  
            # k = i-L so k corresponds to number which 
            # matches in [L,R] interval. 
            k = i - l 
  
            # if Z[k] is less than remaining interval 
            # then Z[i] will be equal to Z[k]. 
            # For example, str = "ababab", i = 3, R = 5 
            # and L = 2 
            if z[k] < r - i + 1: 
                z[i] = z[k] 
  
            # For example str = "aaaaaa" and i = 2,  
            # R is 5, L is 0 
            else: 
  
                # else start from R and check manually 
                l = i 
                while r < s_l and cyclic_string[r - l] == cyclic_string[r]: 
                    r += 1
                z[i] = r - l 
                r -= 1

        if z[i] > max_i[1]:
            max_i = (i, z[i])

    if z.count(0) == 1:
        repeated_times = len(z)
        shortest_cycle = s_l // repeated_times
    elif z.count(0) == s_l:
        shortest_cycle = s_l
    elif z[max_i[0]] <= 1:
        shortest_cycle = s_l
    elif max_i[0] > s_l / 2:
        shortest_cycle = s_l
    elif max_i[0] == (s_l - 1) / 2:
        shortest_cycle = s_l
    else:
        if show_debug:
            print(z, max_i, s_l)

        shortest_cycle = max_i[0]

        nn = max_i[0]
        while (nn + max_i[0]) < s_l:

            if z[nn + max_i[0]] != z[nn] - max_i[0]:
                
                shortest_cycle = s_l
                break
            # print(nn + max_i[0])
            nn += max_i[0]
            
    return shortest_cycle


import string
import random

failed_cases = [
    ('mxmx', 2),
    ('gpgp', 2),
    ('trtrtrtr', 2),
    ('rxocrxi', 7),
    ('xueaxurly', 9),
    ('beqqbeety', 9),
    ('eesagiyeesagiyeesagiyeesagiyeesagiyeesagiyeesagiy', 7),
    ('itwitscfa', 9)
]

for ff in failed_cases:
    res = shortestCycle(ff[0])

    if res != ff[1]:
        show_debug = True
        res = shortestCycle(ff[0])
        print("string {}; answer {}; returned value {}".format(ff[0], ff[1], res))
        exit()


cyclic_string = 'ababab'
# check that your code works correctly on provided example
# assert shortestCycle(cyclic_string) == 3, 'Wrong answer'

def get_random_string(length):
    letters = string.ascii_lowercase
    # return ''.join(random.sample(letters, length))
    return ''.join(random.choice(letters) for i in range(length))

def cyclisc_string(s, max_repeat = 4, min_repeat = 1):
    repest_times = random.randrange(min_repeat, max_repeat)

    return s * repest_times, repest_times

test_case = 10000
max_string_len = 10
max_repeat = 20
min_repeat = 1

for n in range(test_case):
    length = random.randrange(1, max_string_len)

    random_string = get_random_string(length)
    repeated_string, repeated_times = cyclisc_string(random_string, max_repeat, min_repeat)

    result = shortestCycle(repeated_string)

    if len(random_string) != result:

        if len(set(list(random_string))) == 1 and result == 1:
            continue

        show_debug = True
        shortestCycle(repeated_string)
        print("failed!! origin_string '{}', repeated_string '{}', repeated_times '{}', wrong result '{}'"
            .format(random_string, repeated_string, repeated_times, result))

        print('tested %d cases' % n)
        break
# Out:
# [0, 0, 14, 0, 12, 0, 10, 0, 8, 0, 6, 0, 4, 0, 2, 0] (2, 14) 16
# failed!! origin_string 'ugug', repeated_string 'ugugugugugugugug', repeated_times '4', wrong result '2'
# tested 819 cases
