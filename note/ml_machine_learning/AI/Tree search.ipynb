# %% [markdown]
# ## Breadth - First Search
# - Exlored
# - Frontier
# - always expand the shallowest path, the shortest path

# %%
function Graph.Search(problem):
    frontier = {[initial]}; explored={}
    loop:
        if frontier is empty return FAIL
        path = remove.choice(frontier)
        s=path.end; add s to explored
        if s is goal: return path
            for a in actions:
                add [path + a->Result(s,a)]
                to frontier 
                unless Result(s,a) in frontier or explored
# Out:
#   File "<ipython-input-2-051f95620471>", line 1
#     function Graph.Search(problem):
#                  ^
# SyntaxError: invalid syntax

# %% [markdown]
# ## Uniform cost search
#
# - always expand the path with lowest total cost
# - always expend the lowest cost node
# - unless explored or Frontier
# - do not terminate when forst reach the goal, keep try the cheapest. until all have been explored and get the cheapest path

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![Selection_002.png](attachment:Selection_002.png)

# %% [markdown]
# ### uniform cost search
#
# ![Selection_003.png](attachment:Selection_003.png)

# %% [markdown]
# ### Greedy best first search
#
# ![Selection_004.png](attachment:Selection_004.png)
#
# ![Selection_005.png](attachment:Selection_005.png)

# %% [markdown]
# ## A* search
#
# ![Selection_006.png](attachment:Selection_006.png)
