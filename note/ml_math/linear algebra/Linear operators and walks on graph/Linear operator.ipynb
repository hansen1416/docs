# %% [markdown]
# A mappling $\varphi: V_1 \to V_2$ is called __linear__ if:
#
# 1) $\forall u,v \in V_1, \varphi(u+v) = \varphi(u) + \varphi(v)$
#
# 1) $\forall u \in V_1, \forall \lambda \in F \;\; \varphi(\lambda u) + \varphi\lambda(u)$
#
# Here $V_1$ and $V_2$ are two vector spaces.
#
# If $V_1=V_2=V$, we call the linear mapping a __linear operator__ on V
#
# __Matrices of linear operators__
#
# A __matrix of a linear mapping__ corresponding to bases $E_1$ in $V_1$ and $E_2$ in $v_2$ is a matrix
#
# $A_{E_1,E_2} = \begin{pmatrix}
# a_11 & \dots & a_{1n} \\
# \vdots & \dots & \vdots \\
# a_{m1} & \dots & a_{mn}
# \end{pmatrix}$,
#
# where the columns are the coordinates of the images of the vectors of the basis $E_1$ in the basis $E_2$
#
# __example__
#
# If a linear operator $A$ transforms
#
# $\binom{-1}{0} \to \binom{a}{b}$ and $\binom{0}{-1} \to \binom{c}{d}$
#
# what is the matrix of $A$
#
# $A \binom{-1}{0} = \binom{a}{b}, A \binom{0}{-1} = \binom{c}{d} \implies A = -\begin{pmatrix}a & c \\ b & d\end{pmatrix}$

# %% [markdown]
# __Change of the basis__
#
# Let $\varphi$ be a linear mapping from the linear space $V_1$ to the linear space $V_2$.
# Let $A_{E_1E_2}$ be a linear mapping matrix in a pair of bases: $E_1$ in the space $V_1$ and $E_2$ in the space $V_2$ and
# let $T_1$ be the transition matrix from $E_1$ to $E^{\prime}_1$ and $T_2$ be the transition matrix from $E_2$ to $E^{\prime}_2$. Then:
#
# $A_{E^{\prime}_1E^{\prime}_2} = T^{-1}_2A_{E_1E_2}T_1$
#
# In the case of linear operator $T_1=T_2=T$ and therefore formula for linear operatiors:
#
# $A_{E^{\prime}} = T^{-1}A_{E}T$

# %% [markdown]
# __Example__
#
# Let matrix of a linear operator $B$ be $\begin{pmatrix}1 & -2 \\ 3 & 1 \end{pmatrix}$ and transformation matrix $T$ be $\begin{pmatrix} 3 & 2 \\ 5 & 3 \end{pmatrix}$
#
# The $B$ in a new basis will be
#
# $B^{\prime} = T^{-1}BT = \begin{pmatrix} 49 & 30 \\ -77 & -47 \end{pmatrix}$

# %% [markdown]
# Proof:
#
# $y=Ax$
#
# $x \in V_1$
#
# $y \in V_2$
#
# $y^{\prime} = T^{-1}_2y \implies y = T_2y^{\prime}$
#
# $x= T_1x^{\prime}$
#
# so $T_2y^{\prime}=AT_1x^{\prime} \implies y^{\prime}=T^{-1}_2AT_1x^{\prime} $
#
# $A^{\prime} = T^{-1}_2AT_1$

# %% [markdown]
# __example__
#
# Let $\vec{v} \in \mathbb{R}^2$ a vector and consider __two different basis__:
#
# $B_v:\vec{v_1},\vec{v_2}$
#
# and
#
# $B_w:\vec{w_1},\vec{w_2}$
#
# Vector $\vec{v}$ can be represented in two ways:
#
# $\vec{v}=a_1 \cdot \vec{v_1} + a_2 \cdot \vec{v_2} = x_1 \cdot \vec{w_1} + x_2 \cdot \vec{w_2}$
#
# or in matrix form:
#
# $\vec{v} = V \cdot a = W \cdot x $
#
# NOTE matricex $V$ and $W$  have the corresponding vectors of the basis as columns
#
# Now suppose we know the components of $\vec{v}$ with respect to basis $B_v$ and we want to find the $x$ components of $\vec{v}$ with respect to basis $B_w$, thus:
#
# $V \cdot a = W \cdot x \implies x = W^{-1} Va = Ma$
#
# matrix $M=W^{-1}V$ is the __matrix of change of basis__ from $B_v$ to $B_w$.
#
# NOTE this concept can be extended to vectors $\vec{v} in \mathbb{R}^n$

# %% [markdown]
# __example__
#
# Let $T: \mathbb{R}^2 \to \mathbb{R}^2$ be defined by $T(a,b)=(a+2b, 3a-b)$. Let $B = \{(1,1),(1,0)\}$ and $C = \{(4,7),(4,8)\}$. Find $[T]_B$ and $[T]_C$ and show that $[T]_C=Q^{-1} \cdot [T]_B \cdot Q$ for some invertible matrix $Q$.
#
# We know the matrix for canonical basis:
#
# $T_A = \begin{bmatrix} 1 & 2 \\ 3 & -1 \end{bmatrix}$
#
# And two other basis
#
# $B=\{(1,1),(1,0)\}$
#
# $C = \{(4,7),(4,8)\}$
#
# And we have to find the matrices $T_B$ and $T_C$ with respect to these two basis
#
# Let $w$ be any vector given in the canonical basis and indicate with: $v_1=(1,1)$ and $v_2=(1,0)$ the two vectors of basis $B$, also given with respect to the canonical basis.
#
# We are looking for the coefficient $x_1$ and $x_2$ such that:
#
# $w=x_1 \cdot v_1 + x_2 \cdot v_2$
#
# or in matrix form:
#
# $w= V \cdot x$
#
# $V=\begin{bmatrix} 1 & 1 \\ 1 & 0 \end{bmatrix}$
#
# Note that $V$ contains as column the vectors of the new basis with respect to the conanical basis.
# It is important to note that $V$ represent the __matrix of change of basis__ from $B$ to the canonical.
#
# Thus, the components of any vector $w$ with respect to the new basis are given by:
#
# $x=V^{-1} \cdot w$
#
# $V^{-1}=\begin{bmatrix} 0 & 1 \\ 1 & -1 \end{bmatrix}$
#
# Thus  $V^{-1}$ represent the __matrix of change of basis__ from canonical to the new basis $B$.
#
# The mapping of $w$ with respect to the canonical basis is given by:
#
# $u=T_A \cdot w$
#
# Since we are looking for the matrix $T_B$ that represent $T$ with respect to the new basis $B$, let's plug in the change of basis:
#
# $u=V \cdot y$
#
# $w=V \cdot x$
#
# to obtain:
#
# $u=T_A \cdot w \iff V \cdot y = T_A \cdot V \cdot x \iff y = V^{1} \cdot T_A \cdot V \cdot x = T_B \cdot x$
#
# Thus the matrix:
#
# $T_B = V^{1} \cdot T_A \cdot V$
#
# represent the __transformation with respect to the new basis B__.
#
# $T_B = \begin{bmatrix} 0 & 1 \\ 1 & -1 \end{bmatrix} \begin{bmatrix} 1 & 2 \\ 3 & -1 \end{bmatrix} \begin{bmatrix} 1 & 1 \\ 1 & 0 \end{bmatrix} = \begin{bmatrix} 2 & 3\\ 1 & -2 \end{bmatrix}$
#
# For $T_C$ you can proceed in the same manner finding:
#
# $T_C=W^{-1} \cdot T_A \cdot W $
#
# Now since
#
# $T_B = V^{-1} \cdot T_A \cdot V \implies T_A = V \cdot T_B \cdot V^{-1} $
#
# $T_C = W^{-1} \cdot T_A \cdot W = W^{-1} \cdot V \cdot T_B \cdot V^{-1} \cdot W $
